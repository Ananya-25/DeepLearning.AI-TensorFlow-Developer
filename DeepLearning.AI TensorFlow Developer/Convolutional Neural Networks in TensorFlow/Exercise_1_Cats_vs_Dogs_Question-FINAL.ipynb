# %%
# ATTENTION: Please do not alter any of the provided code in the exercise. Only add your own code where indicated
# ATTENTION: Please do not add or remove any cells in the exercise. The grader will check specific cells based on the cell position.
# ATTENTION: Please use the provided epoch values when training.

# In this exercise you will train a CNN on the FULL Cats-v-dogs dataset
# This will require you doing a lot of data preprocessing because
# the dataset isn't split into training and validation for you
# This code block has all the required inputs
import os
import zipfile
import random
import tensorflow as tf
import shutil
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
from os import getcwd

# %%
path_cats_and_dogs = f"{getcwd()}/../tmp2/cats-and-dogs.zip"
shutil.rmtree('/tmp')

local_zip = path_cats_and_dogs
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
print(len(os.listdir('/tmp/PetImages/Cat/')))
print(len(os.listdir('/tmp/PetImages/Dog/')))

# Expected Output:
# 1500
# 1500
# Out:
# 1500
# 1500

# %%
# Use os.mkdir to create your directories
# You will need a directory for cats-v-dogs, and subdirectories for training
# and testing. These in turn will need subdirectories for 'cats' and 'dogs'
try:
    os.mkdir('/tmp/cats-v-dogs')
    os.mkdir('/tmp/cats-v-dogs/training')
    os.mkdir('/tmp/cats-v-dogs/testing')
    os.mkdir('/tmp/cats-v-dogs/training/cats')
    os.mkdir('/tmp/cats-v-dogs/training/dogs')
    os.mkdir('/tmp/cats-v-dogs/testing/cats')
    os.mkdir('/tmp/cats-v-dogs/testing/dogs')  
except OSError:
    pass

# %%
# Write a python function called split_data which takes
# a SOURCE directory containing the files
# a TRAINING directory that a portion of the files will be copied to
# a TESTING directory that a portion of the files will be copie to
# a SPLIT SIZE to determine the portion
# The files should also be randomized, so that the training set is a random
# X% of the files, and the test set is the remaining files
# SO, for example, if SOURCE is PetImages/Cat, and SPLIT SIZE is .9
# Then 90% of the images in PetImages/Cat will be copied to the TRAINING dir
# and 10% of the images will be copied to the TESTING dir
# Also -- All images should be checked, and if they have a zero file length,
# they will not be copied over
#
# os.listdir(DIRECTORY) gives you a listing of the contents of that directory
# os.path.getsize(PATH) gives you the size of the file
# copyfile(source, destination) copies a file from source to destination
# random.sample(list, len(list)) shuffles a list
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):
# YOUR CODE STARTS HERE
    all_files = []
    print(SOURCE)
    print(TRAINING)
    print(TESTING)
    for file_name in os.listdir(SOURCE):
        file_path = SOURCE + file_name
        print(file_path)

        if os.path.getsize(file_path):
            all_files.append(file_name)
        else:
            print('{} is zero length'.format(file_name))
    
    shuf = random.sample(all_files, len(all_files))
    
    train_set = shuf[:int(len(all_files) * SPLIT_SIZE)]
    test_set = shuf[int(len(all_files) * SPLIT_SIZE):]
    
    for file_name in train_set:
        copyfile(SOURCE + file_name, TRAINING + file_name)
        
    for file_name in test_set:
        copyfile(SOURCE + file_name, TESTING + file_name)
# YOUR CODE ENDS HERE


CAT_SOURCE_DIR = "/tmp/PetImages/Cat/"
TRAINING_CATS_DIR = "/tmp/cats-v-dogs/training/cats/"
TESTING_CATS_DIR = "/tmp/cats-v-dogs/testing/cats/"
DOG_SOURCE_DIR = "/tmp/PetImages/Dog/"
TRAINING_DOGS_DIR = "/tmp/cats-v-dogs/training/dogs/"
TESTING_DOGS_DIR = "/tmp/cats-v-dogs/testing/dogs/"

split_size = .9
split_data(CAT_SOURCE_DIR, TRAINING_CATS_DIR, TESTING_CATS_DIR, split_size)
split_data(DOG_SOURCE_DIR, TRAINING_DOGS_DIR, TESTING_DOGS_DIR, split_size)
# Out:
# /tmp/PetImages/Cat/
# /tmp/cats-v-dogs/training/cats/
# /tmp/cats-v-dogs/testing/cats/
# /tmp/PetImages/Cat/cat.778.jpg
# /tmp/PetImages/Cat/cat.319.jpg
# /tmp/PetImages/Cat/cat.187.jpg
# /tmp/PetImages/Cat/cat.620.jpg
# /tmp/PetImages/Cat/cat.2102.jpg
# /tmp/PetImages/Cat/cat.994.jpg
# /tmp/PetImages/Cat/cat.241.jpg
# /tmp/PetImages/Cat/cat.2215.jpg
# /tmp/PetImages/Cat/cat.945.jpg
# /tmp/PetImages/Cat/cat.537.jpg
# /tmp/PetImages/Cat/cat.290.jpg
# /tmp/PetImages/Cat/cat.156.jpg
# /tmp/PetImages/Cat/cat.2496.jpg
# /tmp/PetImages/Cat/cat.2331.jpg
# /tmp/PetImages/Cat/cat.413.jpg
# /tmp/PetImages/Cat/cat.861.jpg
# /tmp/PetImages/Cat/cat.704.jpg
# /tmp/PetImages/Cat/cat.2026.jpg
# /tmp/PetImages/Cat/cat.365.jpg
# /tmp/PetImages/Cat/cat.2447.jpg
# /tmp/PetImages/Cat/cat.939.jpg
# /tmp/PetImages/Cat/cat.2269.jpg
# /tmp/PetImages/Cat/cat.2336.jpg
# /tmp/PetImages/Cat/cat.2491.jpg
# /tmp/PetImages/Cat/cat.866.jpg
# /tmp/PetImages/Cat/cat.414.jpg
# /tmp/PetImages/Cat/cat.703.jpg
# /tmp/PetImages/Cat/cat.2021.jpg
# /tmp/PetImages/Cat/cat.362.jpg
# /tmp/PetImages/Cat/cat.2440.jpg
# /tmp/PetImages/Cat/cat.2179.jpg
# /tmp/PetImages/Cat/cat.468.jpg
# /tmp/PetImages/Cat/cat.627.jpg
# /tmp/PetImages/Cat/cat.180.jpg
# /tmp/PetImages/Cat/cat.2105.jpg
# /tmp/PetImages/Cat/cat.246.jpg
# /tmp/PetImages/Cat/cat.993.jpg
# /tmp/PetImages/Cat/cat.2212.jpg
# /tmp/PetImages/Cat/cat.297.jpg
# /tmp/PetImages/Cat/cat.530.jpg
# /tmp/PetImages/Cat/cat.942.jpg
# /tmp/PetImages/Cat/cat.151.jpg
# /tmp/PetImages/Cat/cat.868.jpg
# /tmp/PetImages/Cat/cat.2338.jpg
# /tmp/PetImages/Cat/cat.74.jpg
# /tmp/PetImages/Cat/cat.655.jpg
# /tmp/PetImages/Cat/cat.2177.jpg
# /tmp/PetImages/Cat/cat.593.jpg
# /tmp/PetImages/Cat/cat.234.jpg
# /tmp/PetImages/Cat/cat.2260.jpg
# /tmp/PetImages/Cat/cat.542.jpg
# /tmp/PetImages/Cat/cat.930.jpg
# /tmp/PetImages/Cat/cat.123.jpg
# /tmp/PetImages/Cat/cat.684.jpg
# /tmp/PetImages/Cat/cat.2344.jpg
# /tmp/PetImages/Cat/cat.814.jpg
# /tmp/PetImages/Cat/cat.466.jpg
# /tmp/PetImages/Cat/cat.2082.jpg
# /tmp/PetImages/Cat/cat.771.jpg
# /tmp/PetImages/Cat/cat.2053.jpg
# /tmp/PetImages/Cat/cat.310.jpg
# /tmp/PetImages/Cat/cat.2432.jpg
# /tmp/PetImages/Cat/cat.2395.jpg
# /tmp/PetImages/Cat/cat.629.jpg
# /tmp/PetImages/Cat/cat.248.jpg
# /tmp/PetImages/Cat/cat.299.jpg
# /tmp/PetImages/Cat/cat.2343.jpg
# /tmp/PetImages/Cat/cat.461.jpg
# /tmp/PetImages/Cat/cat.813.jpg
# /tmp/PetImages/Cat/cat.2085.jpg
# /tmp/PetImages/Cat/cat.776.jpg
# /tmp/PetImages/Cat/cat.2054.jpg
# /tmp/PetImages/Cat/cat.317.jpg
# /tmp/PetImages/Cat/cat.2392.jpg
# /tmp/PetImages/Cat/cat.2435.jpg
# /tmp/PetImages/Cat/cat.189.jpg
# /tmp/PetImages/Cat/cat.539.jpg
# /tmp/PetImages/Cat/cat.158.jpg
# /tmp/PetImages/Cat/cat.2498.jpg
# /tmp/PetImages/Cat/cat.2028.jpg
# /tmp/PetImages/Cat/cat.2449.jpg
# /tmp/PetImages/Cat/cat.652.jpg
# /tmp/PetImages/Cat/cat.73.jpg
# /tmp/PetImages/Cat/cat.2170.jpg
# /tmp/PetImages/Cat/cat.233.jpg
# /tmp/PetImages/Cat/cat.594.jpg
# /tmp/PetImages/Cat/cat.2267.jpg
# /tmp/PetImages/Cat/cat.937.jpg
# /tmp/PetImages/Cat/cat.545.jpg
# /tmp/PetImages/Cat/cat.683.jpg
# /tmp/PetImages/Cat/cat.124.jpg
# /tmp/PetImages/Cat/cat.322.jpg
# /tmp/PetImages/Cat/cat.485.jpg
# /tmp/PetImages/Cat/cat.2400.jpg
# /tmp/PetImages/Cat/cat.743.jpg
# /tmp/PetImages/Cat/cat.2061.jpg
# /tmp/PetImages/Cat/cat.792.jpg
# /tmp/PetImages/Cat/cat.2376.jpg
# /tmp/PetImages/Cat/cat.454.jpg
# /tmp/PetImages/Cat/cat.826.jpg
# /tmp/PetImages/Cat/cat.2139.jpg
# /tmp/PetImages/Cat/cat.428.jpg
# /tmp/PetImages/Cat/cat.2194.jpg
# /tmp/PetImages/Cat/cat.97.jpg
# /tmp/PetImages/Cat/cat.111.jpg
# /tmp/PetImages/Cat/cat.2252.jpg
# /tmp/PetImages/Cat/cat.902.jpg
# /tmp/PetImages/Cat/cat.570.jpg
# /tmp/PetImages/Cat/cat.206.jpg
# /tmp/PetImages/Cat/cat.2283.jpg
# /tmp/PetImages/Cat/cat.667.jpg
# /tmp/PetImages/Cat/cat.46.jpg
# /tmp/PetImages/Cat/cat.2145.jpg
# /tmp/PetImages/Cat/cat.359.jpg
# /tmp/PetImages/Cat/cat.738.jpg
# /tmp/PetImages/Cat/cat.388.jpg
# /tmp/PetImages/Cat/cat.2193.jpg
# /tmp/PetImages/Cat/cat.116.jpg
# /tmp/PetImages/Cat/cat.90.jpg
# /tmp/PetImages/Cat/cat.2255.jpg
# /tmp/PetImages/Cat/cat.577.jpg
# /tmp/PetImages/Cat/cat.905.jpg
# /tmp/PetImages/Cat/cat.201.jpg
# /tmp/PetImages/Cat/cat.2284.jpg
# /tmp/PetImages/Cat/cat.41.jpg
# /tmp/PetImages/Cat/cat.660.jpg
# /tmp/PetImages/Cat/cat.2142.jpg
# /tmp/PetImages/Cat/cat.482.jpg
# /tmp/PetImages/Cat/cat.325.jpg
# /tmp/PetImages/Cat/cat.2407.jpg
# /tmp/PetImages/Cat/cat.744.jpg
# /tmp/PetImages/Cat/cat.2066.jpg
# /tmp/PetImages/Cat/cat.795.jpg
# /tmp/PetImages/Cat/cat.2371.jpg
# /tmp/PetImages/Cat/cat.821.jpg
# /tmp/PetImages/Cat/cat.453.jpg
# /tmp/PetImages/Cat/cat.979.jpg
# /tmp/PetImages/Cat/cat.2229.jpg
# /tmp/PetImages/Cat/cat.357.jpg
# /tmp/PetImages/Cat/cat.882.jpg
# /tmp/PetImages/Cat/cat.2475.jpg
# /tmp/PetImages/Cat/cat.736.jpg
# /tmp/PetImages/Cat/cat.2014.jpg
# /tmp/PetImages/Cat/cat.2303.jpg
# /tmp/PetImages/Cat/cat.386.jpg
# /tmp/PetImages/Cat/cat.853.jpg
# /tmp/PetImages/Cat/cat.421.jpg
# /tmp/PetImages/Cat/cat.118.jpg
# /tmp/PetImages/Cat/cat.579.jpg
# /tmp/PetImages/Cat/cat.2409.jpg
# /tmp/PetImages/Cat/cat.2068.jpg
# /tmp/PetImages/Cat/cat.164.jpg
# /tmp/PetImages/Cat/cat.2227.jpg
# /tmp/PetImages/Cat/cat.505.jpg
# /tmp/PetImages/Cat/cat.977.jpg
# /tmp/PetImages/Cat/cat.273.jpg
# /tmp/PetImages/Cat/cat.612.jpg
# /tmp/PetImages/Cat/cat.33.jpg
# /tmp/PetImages/Cat/cat.2130.jpg
# /tmp/PetImages/Cat/cat.828.jpg
# /tmp/PetImages/Cat/cat.2378.jpg
# /tmp/PetImages/Cat/cat.163.jpg
# /tmp/PetImages/Cat/cat.2220.jpg
# /tmp/PetImages/Cat/cat.970.jpg
# /tmp/PetImages/Cat/cat.502.jpg
# /tmp/PetImages/Cat/cat.274.jpg
# /tmp/PetImages/Cat/cat.34.jpg
# /tmp/PetImages/Cat/cat.615.jpg
# /tmp/PetImages/Cat/cat.2137.jpg
# /tmp/PetImages/Cat/cat.885.jpg
# /tmp/PetImages/Cat/cat.350.jpg
# /tmp/PetImages/Cat/cat.2472.jpg
# /tmp/PetImages/Cat/cat.731.jpg
# /tmp/PetImages/Cat/cat.2013.jpg
# /tmp/PetImages/Cat/cat.2304.jpg
# /tmp/PetImages/Cat/cat.426.jpg
# /tmp/PetImages/Cat/cat.854.jpg
# /tmp/PetImages/Cat/cat.381.jpg
# /tmp/PetImages/Cat/cat.99.jpg
# /tmp/PetImages/Cat/cat.208.jpg
# /tmp/PetImages/Cat/cat.48.jpg
# /tmp/PetImages/Cat/cat.669.jpg
# /tmp/PetImages/Cat/cat.265.jpg
# /tmp/PetImages/Cat/cat.2126.jpg
# /tmp/PetImages/Cat/cat.25.jpg
# /tmp/PetImages/Cat/cat.604.jpg
# /tmp/PetImages/Cat/cat.172.jpg
# /tmp/PetImages/Cat/cat.513.jpg
# /tmp/PetImages/Cat/cat.961.jpg
# /tmp/PetImages/Cat/cat.2231.jpg
# /tmp/PetImages/Cat/cat.2369.jpg
# /tmp/PetImages/Cat/cat.839.jpg
# /tmp/PetImages/Cat/cat.219.jpg
# /tmp/PetImages/Cat/cat.59.jpg
# /tmp/PetImages/Cat/cat.678.jpg
# /tmp/PetImages/Cat/cat.88.jpg
# /tmp/PetImages/Cat/cat.390.jpg
# /tmp/PetImages/Cat/cat.845.jpg
# /tmp/PetImages/Cat/cat.437.jpg
# /tmp/PetImages/Cat/cat.2315.jpg
# /tmp/PetImages/Cat/cat.2463.jpg
# /tmp/PetImages/Cat/cat.341.jpg
# /tmp/PetImages/Cat/cat.894.jpg
# /tmp/PetImages/Cat/cat.2002.jpg
# /tmp/PetImages/Cat/cat.720.jpg
# /tmp/PetImages/Cat/cat.109.jpg
# /tmp/PetImages/Cat/cat.568.jpg
# /tmp/PetImages/Cat/cat.430.jpg
# /tmp/PetImages/Cat/cat.842.jpg
# /tmp/PetImages/Cat/cat.397.jpg
# /tmp/PetImages/Cat/cat.2312.jpg
# /tmp/PetImages/Cat/cat.2464.jpg
# /tmp/PetImages/Cat/cat.893.jpg
# /tmp/PetImages/Cat/cat.346.jpg
# /tmp/PetImages/Cat/cat.2005.jpg
# /tmp/PetImages/Cat/cat.727.jpg
# /tmp/PetImages/Cat/cat.262.jpg
# /tmp/PetImages/Cat/cat.2121.jpg
# /tmp/PetImages/Cat/cat.603.jpg
# /tmp/PetImages/Cat/cat.22.jpg
# /tmp/PetImages/Cat/cat.175.jpg
# /tmp/PetImages/Cat/cat.966.jpg
# /tmp/PetImages/Cat/cat.514.jpg
# /tmp/PetImages/Cat/cat.2236.jpg
# /tmp/PetImages/Cat/cat.2418.jpg
# /tmp/PetImages/Cat/cat.2079.jpg
# /tmp/PetImages/Cat/cat.2295.jpg
# /tmp/PetImages/Cat/cat.210.jpg
# /tmp/PetImages/Cat/cat.2153.jpg
# /tmp/PetImages/Cat/cat.50.jpg
# /tmp/PetImages/Cat/cat.671.jpg
# /tmp/PetImages/Cat/cat.107.jpg
# /tmp/PetImages/Cat/cat.81.jpg
# /tmp/PetImages/Cat/cat.2182.jpg
# /tmp/PetImages/Cat/cat.914.jpg
# /tmp/PetImages/Cat/cat.566.jpg
# /tmp/PetImages/Cat/cat.2244.jpg
# /tmp/PetImages/Cat/cat.399.jpg
# /tmp/PetImages/Cat/cat.348.jpg
# /tmp/PetImages/Cat/cat.729.jpg
# /tmp/PetImages/Cat/cat.2238.jpg
# /tmp/PetImages/Cat/cat.968.jpg
# /tmp/PetImages/Cat/cat.784.jpg
# /tmp/PetImages/Cat/cat.442.jpg
# /tmp/PetImages/Cat/cat.830.jpg
# /tmp/PetImages/Cat/cat.2360.jpg
# /tmp/PetImages/Cat/cat.2416.jpg
# /tmp/PetImages/Cat/cat.334.jpg
# /tmp/PetImages/Cat/cat.493.jpg
# /tmp/PetImages/Cat/cat.2077.jpg
# /tmp/PetImages/Cat/cat.755.jpg
# /tmp/PetImages/Cat/cat.2128.jpg
# /tmp/PetImages/Cat/cat.783.jpg
# /tmp/PetImages/Cat/cat.837.jpg
# /tmp/PetImages/Cat/cat.445.jpg
# /tmp/PetImages/Cat/cat.2367.jpg
# /tmp/PetImages/Cat/cat.2411.jpg
# /tmp/PetImages/Cat/cat.494.jpg
# /tmp/PetImages/Cat/cat.333.jpg
# /tmp/PetImages/Cat/cat.2070.jpg
# /tmp/PetImages/Cat/cat.752.jpg
# /tmp/PetImages/Cat/cat.2292.jpg
# /tmp/PetImages/Cat/cat.217.jpg
# /tmp/PetImages/Cat/cat.2154.jpg
# /tmp/PetImages/Cat/cat.676.jpg
# /tmp/PetImages/Cat/cat.57.jpg
# /tmp/PetImages/Cat/cat.86.jpg
# /tmp/PetImages/Cat/cat.100.jpg
# /tmp/PetImages/Cat/cat.2185.jpg
# /tmp/PetImages/Cat/cat.561.jpg
# /tmp/PetImages/Cat/cat.913.jpg
# /tmp/PetImages/Cat/cat.2243.jpg
# /tmp/PetImages/Cat/cat.439.jpg
# /tmp/PetImages/Cat/cat.528.jpg
# /tmp/PetImages/Cat/cat.149.jpg
# /tmp/PetImages/Cat/cat.198.jpg
# /tmp/PetImages/Cat/cat.2045.jpg
# /tmp/PetImages/Cat/cat.767.jpg
# /tmp/PetImages/Cat/cat.2424.jpg
# /tmp/PetImages/Cat/cat.2383.jpg
# /tmp/PetImages/Cat/cat.306.jpg
# /tmp/PetImages/Cat/cat.802.jpg
# /tmp/PetImages/Cat/cat.470.jpg
# /tmp/PetImages/Cat/cat.9.jpg
# /tmp/PetImages/Cat/cat.2352.jpg
# /tmp/PetImages/Cat/cat.2094.jpg
# /tmp/PetImages/Cat/cat.554.jpg
# /tmp/PetImages/Cat/cat.926.jpg
# /tmp/PetImages/Cat/cat.2276.jpg
# /tmp/PetImages/Cat/cat.135.jpg
# /tmp/PetImages/Cat/cat.692.jpg
# /tmp/PetImages/Cat/cat.2161.jpg
# /tmp/PetImages/Cat/cat.643.jpg
# /tmp/PetImages/Cat/cat.62.jpg
# /tmp/PetImages/Cat/cat.585.jpg
# /tmp/PetImages/Cat/cat.222.jpg
# /tmp/PetImages/Cat/cat.2039.jpg
# /tmp/PetImages/Cat/cat.2458.jpg
# /tmp/PetImages/Cat/cat.2489.jpg
# /tmp/PetImages/Cat/cat.921.jpg
# /tmp/PetImages/Cat/cat.553.jpg
# /tmp/PetImages/Cat/cat.2271.jpg
# /tmp/PetImages/Cat/cat.695.jpg
# /tmp/PetImages/Cat/cat.132.jpg
# /tmp/PetImages/Cat/cat.2166.jpg
# /tmp/PetImages/Cat/cat.65.jpg
# /tmp/PetImages/Cat/cat.644.jpg
# /tmp/PetImages/Cat/cat.225.jpg
# /tmp/PetImages/Cat/cat.582.jpg
# /tmp/PetImages/Cat/cat.2329.jpg
# /tmp/PetImages/Cat/cat.879.jpg
# /tmp/PetImages/Cat/cat.288.jpg
# /tmp/PetImages/Cat/cat.19.jpg
# /tmp/PetImages/Cat/cat.638.jpg
# /tmp/PetImages/Cat/cat.259.jpg
# /tmp/PetImages/Cat/cat.2042.jpg
# /tmp/PetImages/Cat/cat.760.jpg
# /tmp/PetImages/Cat/cat.2384.jpg
# /tmp/PetImages/Cat/cat.2423.jpg
# /tmp/PetImages/Cat/cat.301.jpg
# /tmp/PetImages/Cat/cat.477.jpg
# /tmp/PetImages/Cat/cat.805.jpg
# /tmp/PetImages/Cat/cat.2355.jpg
# /tmp/PetImages/Cat/cat.2093.jpg
# /tmp/PetImages/Cat/cat.2168.jpg
# /tmp/PetImages/Cat/cat.2030.jpg
# /tmp/PetImages/Cat/cat.712.jpg
# /tmp/PetImages/Cat/cat.2451.jpg
# /tmp/PetImages/Cat/cat.373.jpg
# /tmp/PetImages/Cat/cat.405.jpg
# /tmp/PetImages/Cat/cat.877.jpg
# /tmp/PetImages/Cat/cat.2480.jpg
# /tmp/PetImages/Cat/cat.2327.jpg
# /tmp/PetImages/Cat/cat.953.jpg
# /tmp/PetImages/Cat/cat.521.jpg
# /tmp/PetImages/Cat/cat.286.jpg
# /tmp/PetImages/Cat/cat.2203.jpg
# /tmp/PetImages/Cat/cat.140.jpg
# /tmp/PetImages/Cat/cat.2114.jpg
# /tmp/PetImages/Cat/cat.191.jpg
# /tmp/PetImages/Cat/cat.636.jpg
# /tmp/PetImages/Cat/cat.17.jpg
# /tmp/PetImages/Cat/cat.982.jpg
# /tmp/PetImages/Cat/cat.257.jpg
# /tmp/PetImages/Cat/cat.479.jpg
# /tmp/PetImages/Cat/cat.0.jpg
# /tmp/PetImages/Cat/cat.281.jpg
# /tmp/PetImages/Cat/cat.526.jpg
# /tmp/PetImages/Cat/cat.954.jpg
# /tmp/PetImages/Cat/cat.2204.jpg
# /tmp/PetImages/Cat/cat.147.jpg
# /tmp/PetImages/Cat/cat.2113.jpg
# /tmp/PetImages/Cat/cat.10.jpg
# /tmp/PetImages/Cat/cat.631.jpg
# /tmp/PetImages/Cat/cat.196.jpg
# /tmp/PetImages/Cat/cat.250.jpg
# /tmp/PetImages/Cat/cat.985.jpg
# /tmp/PetImages/Cat/cat.769.jpg
# /tmp/PetImages/Cat/cat.308.jpg
# /tmp/PetImages/Cat/cat.7.jpg
# /tmp/PetImages/Cat/cat.2278.jpg
# /tmp/PetImages/Cat/cat.928.jpg
# /tmp/PetImages/Cat/cat.2037.jpg
# /tmp/PetImages/Cat/cat.715.jpg
# /tmp/PetImages/Cat/cat.2456.jpg
# /tmp/PetImages/Cat/cat.374.jpg
# /tmp/PetImages/Cat/cat.870.jpg
# /tmp/PetImages/Cat/cat.402.jpg
# /tmp/PetImages/Cat/cat.2320.jpg
# /tmp/PetImages/Cat/cat.2487.jpg
# /tmp/PetImages/Cat/cat.2379.jpg
# /tmp/PetImages/Cat/cat.829.jpg
# /tmp/PetImages/Cat/cat.162.jpg
# /tmp/PetImages/Cat/cat.971.jpg
# /tmp/PetImages/Cat/cat.503.jpg
# /tmp/PetImages/Cat/cat.2221.jpg
# /tmp/PetImages/Cat/cat.275.jpg
# /tmp/PetImages/Cat/cat.2136.jpg
# /tmp/PetImages/Cat/cat.35.jpg
# /tmp/PetImages/Cat/cat.614.jpg
# /tmp/PetImages/Cat/cat.2473.jpg
# /tmp/PetImages/Cat/cat.351.jpg
# /tmp/PetImages/Cat/cat.884.jpg
# /tmp/PetImages/Cat/cat.2012.jpg
# /tmp/PetImages/Cat/cat.730.jpg
# /tmp/PetImages/Cat/cat.380.jpg
# /tmp/PetImages/Cat/cat.427.jpg
# /tmp/PetImages/Cat/cat.855.jpg
# /tmp/PetImages/Cat/cat.2305.jpg
# /tmp/PetImages/Cat/cat.98.jpg
# /tmp/PetImages/Cat/cat.209.jpg
# /tmp/PetImages/Cat/cat.49.jpg
# /tmp/PetImages/Cat/cat.668.jpg
# /tmp/PetImages/Cat/cat.2474.jpg
# /tmp/PetImages/Cat/cat.883.jpg
# /tmp/PetImages/Cat/cat.356.jpg
# /tmp/PetImages/Cat/cat.2015.jpg
# /tmp/PetImages/Cat/cat.737.jpg
# /tmp/PetImages/Cat/cat.852.jpg
# /tmp/PetImages/Cat/cat.420.jpg
# /tmp/PetImages/Cat/cat.387.jpg
# /tmp/PetImages/Cat/cat.2302.jpg
# /tmp/PetImages/Cat/cat.119.jpg
# /tmp/PetImages/Cat/cat.578.jpg
# /tmp/PetImages/Cat/cat.2408.jpg
# /tmp/PetImages/Cat/cat.2069.jpg
# /tmp/PetImages/Cat/cat.165.jpg
# /tmp/PetImages/Cat/cat.504.jpg
# /tmp/PetImages/Cat/cat.976.jpg
# /tmp/PetImages/Cat/cat.2226.jpg
# /tmp/PetImages/Cat/cat.272.jpg
# /tmp/PetImages/Cat/cat.2131.jpg
# /tmp/PetImages/Cat/cat.613.jpg
# /tmp/PetImages/Cat/cat.32.jpg
# /tmp/PetImages/Cat/cat.358.jpg
# /tmp/PetImages/Cat/cat.739.jpg
# /tmp/PetImages/Cat/cat.389.jpg
# /tmp/PetImages/Cat/cat.117.jpg
# /tmp/PetImages/Cat/cat.91.jpg
# /tmp/PetImages/Cat/cat.2192.jpg
# /tmp/PetImages/Cat/cat.576.jpg
# /tmp/PetImages/Cat/cat.904.jpg
# /tmp/PetImages/Cat/cat.2254.jpg
# /tmp/PetImages/Cat/cat.2285.jpg
# /tmp/PetImages/Cat/cat.200.jpg
# /tmp/PetImages/Cat/cat.2143.jpg
# /tmp/PetImages/Cat/cat.40.jpg
# /tmp/PetImages/Cat/cat.661.jpg
# /tmp/PetImages/Cat/cat.2406.jpg
# /tmp/PetImages/Cat/cat.324.jpg
# /tmp/PetImages/Cat/cat.483.jpg
# /tmp/PetImages/Cat/cat.2067.jpg
# /tmp/PetImages/Cat/cat.745.jpg
# /tmp/PetImages/Cat/cat.794.jpg
# /tmp/PetImages/Cat/cat.820.jpg
# /tmp/PetImages/Cat/cat.452.jpg
# /tmp/PetImages/Cat/cat.2370.jpg
# /tmp/PetImages/Cat/cat.2228.jpg
# /tmp/PetImages/Cat/cat.978.jpg
# /tmp/PetImages/Cat/cat.2401.jpg
# /tmp/PetImages/Cat/cat.484.jpg
# /tmp/PetImages/Cat/cat.323.jpg
# /tmp/PetImages/Cat/cat.2060.jpg
# /tmp/PetImages/Cat/cat.742.jpg
# /tmp/PetImages/Cat/cat.793.jpg
# /tmp/PetImages/Cat/cat.455.jpg
# /tmp/PetImages/Cat/cat.827.jpg
# /tmp/PetImages/Cat/cat.2377.jpg
# /tmp/PetImages/Cat/cat.2138.jpg
# /tmp/PetImages/Cat/cat.429.jpg
# /tmp/PetImages/Cat/cat.96.jpg
# /tmp/PetImages/Cat/cat.110.jpg
# /tmp/PetImages/Cat/cat.2195.jpg
# /tmp/PetImages/Cat/cat.903.jpg
# /tmp/PetImages/Cat/cat.571.jpg
# /tmp/PetImages/Cat/cat.2253.jpg
# /tmp/PetImages/Cat/cat.2282.jpg
# /tmp/PetImages/Cat/cat.207.jpg
# /tmp/PetImages/Cat/cat.2144.jpg
# /tmp/PetImages/Cat/cat.666.jpg
# /tmp/PetImages/Cat/cat.47.jpg
# /tmp/PetImages/Cat/cat.460.jpg
# /tmp/PetImages/Cat/cat.812.jpg
# /tmp/PetImages/Cat/cat.2342.jpg
# /tmp/PetImages/Cat/cat.2084.jpg
# /tmp/PetImages/Cat/cat.2055.jpg
# /tmp/PetImages/Cat/cat.777.jpg
# /tmp/PetImages/Cat/cat.2434.jpg
# /tmp/PetImages/Cat/cat.2393.jpg
# /tmp/PetImages/Cat/cat.316.jpg
# /tmp/PetImages/Cat/cat.188.jpg
# /tmp/PetImages/Cat/cat.538.jpg
# /tmp/PetImages/Cat/cat.159.jpg
# /tmp/PetImages/Cat/cat.2499.jpg
# /tmp/PetImages/Cat/cat.2029.jpg
# /tmp/PetImages/Cat/cat.2448.jpg
# /tmp/PetImages/Cat/cat.2171.jpg
# /tmp/PetImages/Cat/cat.653.jpg
# /tmp/PetImages/Cat/cat.72.jpg
# /tmp/PetImages/Cat/cat.595.jpg
# /tmp/PetImages/Cat/cat.232.jpg
# /tmp/PetImages/Cat/cat.936.jpg
# /tmp/PetImages/Cat/cat.544.jpg
# /tmp/PetImages/Cat/cat.2266.jpg
# /tmp/PetImages/Cat/cat.125.jpg
# /tmp/PetImages/Cat/cat.682.jpg
# /tmp/PetImages/Cat/cat.2339.jpg
# /tmp/PetImages/Cat/cat.869.jpg
# /tmp/PetImages/Cat/cat.2176.jpg
# /tmp/PetImages/Cat/cat.75.jpg
# /tmp/PetImages/Cat/cat.654.jpg
# /tmp/PetImages/Cat/cat.235.jpg
# /tmp/PetImages/Cat/cat.592.jpg
# /tmp/PetImages/Cat/cat.543.jpg
# /tmp/PetImages/Cat/cat.931.jpg
# /tmp/PetImages/Cat/cat.2261.jpg
# /tmp/PetImages/Cat/cat.685.jpg
# /tmp/PetImages/Cat/cat.122.jpg
# /tmp/PetImages/Cat/cat.815.jpg
# /tmp/PetImages/Cat/cat.467.jpg
# /tmp/PetImages/Cat/cat.2345.jpg
# /tmp/PetImages/Cat/cat.2083.jpg
# /tmp/PetImages/Cat/cat.2052.jpg
# /tmp/PetImages/Cat/cat.770.jpg
# /tmp/PetImages/Cat/cat.2394.jpg
# /tmp/PetImages/Cat/cat.2433.jpg
# /tmp/PetImages/Cat/cat.311.jpg
# /tmp/PetImages/Cat/cat.628.jpg
# /tmp/PetImages/Cat/cat.249.jpg
# /tmp/PetImages/Cat/cat.298.jpg
# /tmp/PetImages/Cat/cat.867.jpg
# /tmp/PetImages/Cat/cat.415.jpg
# /tmp/PetImages/Cat/cat.2490.jpg
# /tmp/PetImages/Cat/cat.2337.jpg
# /tmp/PetImages/Cat/cat.2020.jpg
# /tmp/PetImages/Cat/cat.702.jpg
# /tmp/PetImages/Cat/cat.2441.jpg
# /tmp/PetImages/Cat/cat.363.jpg
# /tmp/PetImages/Cat/cat.2178.jpg
# /tmp/PetImages/Cat/cat.469.jpg
# /tmp/PetImages/Cat/cat.2104.jpg
# /tmp/PetImages/Cat/cat.181.jpg
# /tmp/PetImages/Cat/cat.626.jpg
# /tmp/PetImages/Cat/cat.992.jpg
# /tmp/PetImages/Cat/cat.247.jpg
# /tmp/PetImages/Cat/cat.531.jpg
# /tmp/PetImages/Cat/cat.943.jpg
# /tmp/PetImages/Cat/cat.296.jpg
# /tmp/PetImages/Cat/cat.2213.jpg
# /tmp/PetImages/Cat/cat.150.jpg
# /tmp/PetImages/Cat/cat.779.jpg
# /tmp/PetImages/Cat/cat.318.jpg
# /tmp/PetImages/Cat/cat.2103.jpg
# /tmp/PetImages/Cat/cat.621.jpg
# /tmp/PetImages/Cat/cat.186.jpg
# /tmp/PetImages/Cat/cat.240.jpg
# /tmp/PetImages/Cat/cat.995.jpg
# /tmp/PetImages/Cat/cat.291.jpg
# /tmp/PetImages/Cat/cat.944.jpg
# /tmp/PetImages/Cat/cat.536.jpg
# /tmp/PetImages/Cat/cat.2214.jpg
# /tmp/PetImages/Cat/cat.157.jpg
# /tmp/PetImages/Cat/cat.412.jpg
# /tmp/PetImages/Cat/cat.860.jpg
# /tmp/PetImages/Cat/cat.2330.jpg
# /tmp/PetImages/Cat/cat.2497.jpg
# /tmp/PetImages/Cat/cat.2027.jpg
# /tmp/PetImages/Cat/cat.705.jpg
# /tmp/PetImages/Cat/cat.2446.jpg
# /tmp/PetImages/Cat/cat.364.jpg
# /tmp/PetImages/Cat/cat.2268.jpg
# /tmp/PetImages/Cat/cat.938.jpg
# /tmp/PetImages/Cat/cat.2205.jpg
# /tmp/PetImages/Cat/cat.527.jpg
# /tmp/PetImages/Cat/cat.955.jpg
# /tmp/PetImages/Cat/cat.280.jpg
# /tmp/PetImages/Cat/cat.146.jpg
# /tmp/PetImages/Cat/cat.11.jpg
# /tmp/PetImages/Cat/cat.197.jpg
# /tmp/PetImages/Cat/cat.630.jpg
# /tmp/PetImages/Cat/cat.2112.jpg
# /tmp/PetImages/Cat/cat.984.jpg
# /tmp/PetImages/Cat/cat.251.jpg
# /tmp/PetImages/Cat/cat.768.jpg
# /tmp/PetImages/Cat/cat.309.jpg
# /tmp/PetImages/Cat/cat.6.jpg
# /tmp/PetImages/Cat/cat.929.jpg
# /tmp/PetImages/Cat/cat.2279.jpg
# /tmp/PetImages/Cat/cat.714.jpg
# /tmp/PetImages/Cat/cat.2036.jpg
# /tmp/PetImages/Cat/cat.375.jpg
# /tmp/PetImages/Cat/cat.2457.jpg
# /tmp/PetImages/Cat/cat.2486.jpg
# /tmp/PetImages/Cat/cat.2321.jpg
# /tmp/PetImages/Cat/cat.871.jpg
# /tmp/PetImages/Cat/cat.403.jpg
# /tmp/PetImages/Cat/cat.2169.jpg
# /tmp/PetImages/Cat/cat.713.jpg
# /tmp/PetImages/Cat/cat.2031.jpg
# /tmp/PetImages/Cat/cat.372.jpg
# /tmp/PetImages/Cat/cat.2450.jpg
# /tmp/PetImages/Cat/cat.2326.jpg
# /tmp/PetImages/Cat/cat.2481.jpg
# /tmp/PetImages/Cat/cat.404.jpg
# /tmp/PetImages/Cat/cat.876.jpg
# /tmp/PetImages/Cat/cat.2202.jpg
# /tmp/PetImages/Cat/cat.287.jpg
# /tmp/PetImages/Cat/cat.952.jpg
# /tmp/PetImages/Cat/cat.520.jpg
# /tmp/PetImages/Cat/cat.141.jpg
# /tmp/PetImages/Cat/cat.637.jpg
# /tmp/PetImages/Cat/cat.190.jpg
# /tmp/PetImages/Cat/cat.16.jpg
# /tmp/PetImages/Cat/cat.2115.jpg
# /tmp/PetImages/Cat/cat.256.jpg
# /tmp/PetImages/Cat/cat.983.jpg
# /tmp/PetImages/Cat/cat.478.jpg
# /tmp/PetImages/Cat/cat.1.jpg
# /tmp/PetImages/Cat/cat.2270.jpg
# /tmp/PetImages/Cat/cat.920.jpg
# /tmp/PetImages/Cat/cat.552.jpg
# /tmp/PetImages/Cat/cat.133.jpg
# /tmp/PetImages/Cat/cat.694.jpg
# /tmp/PetImages/Cat/cat.64.jpg
# /tmp/PetImages/Cat/cat.645.jpg
# /tmp/PetImages/Cat/cat.2167.jpg
# /tmp/PetImages/Cat/cat.583.jpg
# /tmp/PetImages/Cat/cat.224.jpg
# /tmp/PetImages/Cat/cat.878.jpg
# /tmp/PetImages/Cat/cat.2328.jpg
# /tmp/PetImages/Cat/cat.289.jpg
# /tmp/PetImages/Cat/cat.18.jpg
# /tmp/PetImages/Cat/cat.639.jpg
# /tmp/PetImages/Cat/cat.258.jpg
# /tmp/PetImages/Cat/cat.761.jpg
# /tmp/PetImages/Cat/cat.2043.jpg
# /tmp/PetImages/Cat/cat.300.jpg
# /tmp/PetImages/Cat/cat.2422.jpg
# /tmp/PetImages/Cat/cat.2385.jpg
# /tmp/PetImages/Cat/cat.2354.jpg
# /tmp/PetImages/Cat/cat.476.jpg
# /tmp/PetImages/Cat/cat.804.jpg
# /tmp/PetImages/Cat/cat.2092.jpg
# /tmp/PetImages/Cat/cat.529.jpg
# /tmp/PetImages/Cat/cat.148.jpg
# /tmp/PetImages/Cat/cat.199.jpg
# /tmp/PetImages/Cat/cat.766.jpg
# /tmp/PetImages/Cat/cat.2044.jpg
# /tmp/PetImages/Cat/cat.307.jpg
# /tmp/PetImages/Cat/cat.2382.jpg
# /tmp/PetImages/Cat/cat.2425.jpg
# /tmp/PetImages/Cat/cat.2353.jpg
# /tmp/PetImages/Cat/cat.803.jpg
# /tmp/PetImages/Cat/cat.471.jpg
# /tmp/PetImages/Cat/cat.8.jpg
# /tmp/PetImages/Cat/cat.2095.jpg
# /tmp/PetImages/Cat/cat.2277.jpg
# /tmp/PetImages/Cat/cat.555.jpg
# /tmp/PetImages/Cat/cat.927.jpg
# /tmp/PetImages/Cat/cat.693.jpg
# /tmp/PetImages/Cat/cat.134.jpg
# /tmp/PetImages/Cat/cat.642.jpg
# /tmp/PetImages/Cat/cat.63.jpg
# /tmp/PetImages/Cat/cat.2160.jpg
# /tmp/PetImages/Cat/cat.223.jpg
# /tmp/PetImages/Cat/cat.584.jpg
# /tmp/PetImages/Cat/cat.2038.jpg
# /tmp/PetImages/Cat/cat.2459.jpg
# /tmp/PetImages/Cat/cat.2488.jpg
# /tmp/PetImages/Cat/cat.2129.jpg
# /tmp/PetImages/Cat/cat.782.jpg
# /tmp/PetImages/Cat/cat.2366.jpg
# /tmp/PetImages/Cat/cat.836.jpg
# /tmp/PetImages/Cat/cat.444.jpg
# /tmp/PetImages/Cat/cat.332.jpg
# /tmp/PetImages/Cat/cat.495.jpg
# /tmp/PetImages/Cat/cat.2410.jpg
# /tmp/PetImages/Cat/cat.753.jpg
# /tmp/PetImages/Cat/cat.2071.jpg
# /tmp/PetImages/Cat/cat.216.jpg
# /tmp/PetImages/Cat/cat.2293.jpg
# /tmp/PetImages/Cat/cat.677.jpg
# /tmp/PetImages/Cat/cat.56.jpg
# /tmp/PetImages/Cat/cat.2155.jpg
# /tmp/PetImages/Cat/cat.2184.jpg
# /tmp/PetImages/Cat/cat.87.jpg
# /tmp/PetImages/Cat/cat.101.jpg
# /tmp/PetImages/Cat/cat.2242.jpg
# /tmp/PetImages/Cat/cat.560.jpg
# /tmp/PetImages/Cat/cat.912.jpg
# /tmp/PetImages/Cat/cat.438.jpg
# /tmp/PetImages/Cat/cat.211.jpg
# /tmp/PetImages/Cat/cat.2294.jpg
# /tmp/PetImages/Cat/cat.51.jpg
# /tmp/PetImages/Cat/cat.670.jpg
# /tmp/PetImages/Cat/cat.2152.jpg
# /tmp/PetImages/Cat/cat.2183.jpg
# /tmp/PetImages/Cat/cat.106.jpg
# /tmp/PetImages/Cat/cat.80.jpg
# /tmp/PetImages/Cat/cat.2245.jpg
# /tmp/PetImages/Cat/cat.915.jpg
# /tmp/PetImages/Cat/cat.567.jpg
# /tmp/PetImages/Cat/cat.398.jpg
# /tmp/PetImages/Cat/cat.349.jpg
# /tmp/PetImages/Cat/cat.728.jpg
# /tmp/PetImages/Cat/cat.969.jpg
# /tmp/PetImages/Cat/cat.2239.jpg
# /tmp/PetImages/Cat/cat.785.jpg
# /tmp/PetImages/Cat/cat.2361.jpg
# /tmp/PetImages/Cat/cat.443.jpg
# /tmp/PetImages/Cat/cat.831.jpg
# /tmp/PetImages/Cat/cat.492.jpg
# /tmp/PetImages/Cat/cat.335.jpg
# /tmp/PetImages/Cat/cat.2417.jpg
# /tmp/PetImages/Cat/cat.754.jpg
# /tmp/PetImages/Cat/cat.2076.jpg
# /tmp/PetImages/Cat/cat.108.jpg
# /tmp/PetImages/Cat/cat.569.jpg
# /tmp/PetImages/Cat/cat.2313.jpg
# /tmp/PetImages/Cat/cat.396.jpg
# /tmp/PetImages/Cat/cat.431.jpg
# /tmp/PetImages/Cat/cat.843.jpg
# /tmp/PetImages/Cat/cat.347.jpg
# /tmp/PetImages/Cat/cat.892.jpg
# /tmp/PetImages/Cat/cat.2465.jpg
# /tmp/PetImages/Cat/cat.726.jpg
# /tmp/PetImages/Cat/cat.2004.jpg
# /tmp/PetImages/Cat/cat.263.jpg
# /tmp/PetImages/Cat/cat.602.jpg
# /tmp/PetImages/Cat/cat.23.jpg
# /tmp/PetImages/Cat/cat.2120.jpg
# /tmp/PetImages/Cat/cat.174.jpg
# /tmp/PetImages/Cat/cat.2237.jpg
# /tmp/PetImages/Cat/cat.967.jpg
# /tmp/PetImages/Cat/cat.515.jpg
# /tmp/PetImages/Cat/cat.2419.jpg
# /tmp/PetImages/Cat/cat.2078.jpg
# /tmp/PetImages/Cat/cat.264.jpg
# /tmp/PetImages/Cat/cat.24.jpg
# /tmp/PetImages/Cat/cat.605.jpg
# /tmp/PetImages/Cat/cat.2127.jpg
# /tmp/PetImages/Cat/cat.173.jpg
# /tmp/PetImages/Cat/cat.2230.jpg
# /tmp/PetImages/Cat/cat.512.jpg
# /tmp/PetImages/Cat/cat.960.jpg
# /tmp/PetImages/Cat/cat.838.jpg
# /tmp/PetImages/Cat/cat.2368.jpg
# /tmp/PetImages/Cat/cat.218.jpg
# /tmp/PetImages/Cat/cat.58.jpg
# /tmp/PetImages/Cat/cat.679.jpg
# /tmp/PetImages/Cat/cat.89.jpg
# /tmp/PetImages/Cat/cat.2314.jpg
# /tmp/PetImages/Cat/cat.844.jpg
# /tmp/PetImages/Cat/cat.436.jpg
# /tmp/PetImages/Cat/cat.391.jpg
# /tmp/PetImages/Cat/cat.895.jpg
# /tmp/PetImages/Cat/cat.340.jpg
# /tmp/PetImages/Cat/cat.2462.jpg
# /tmp/PetImages/Cat/cat.721.jpg
# /tmp/PetImages/Cat/cat.2003.jpg
# /tmp/PetImages/Cat/cat.699.jpg
# /tmp/PetImages/Cat/cat.229.jpg
# /tmp/PetImages/Cat/cat.69.jpg
# /tmp/PetImages/Cat/cat.648.jpg
# /tmp/PetImages/Cat/cat.2453.jpg
# /tmp/PetImages/Cat/cat.371.jpg
# /tmp/PetImages/Cat/cat.2032.jpg
# /tmp/PetImages/Cat/cat.710.jpg
# /tmp/PetImages/Cat/cat.875.jpg
# /tmp/PetImages/Cat/cat.407.jpg
# /tmp/PetImages/Cat/cat.2325.jpg
# /tmp/PetImages/Cat/cat.2482.jpg
# /tmp/PetImages/Cat/cat.142.jpg
# /tmp/PetImages/Cat/cat.284.jpg
# /tmp/PetImages/Cat/cat.523.jpg
# /tmp/PetImages/Cat/cat.951.jpg
# /tmp/PetImages/Cat/cat.2201.jpg
# /tmp/PetImages/Cat/cat.255.jpg
# /tmp/PetImages/Cat/cat.980.jpg
# /tmp/PetImages/Cat/cat.2116.jpg
# /tmp/PetImages/Cat/cat.15.jpg
# /tmp/PetImages/Cat/cat.634.jpg
# /tmp/PetImages/Cat/cat.193.jpg
# /tmp/PetImages/Cat/cat.2388.jpg
# /tmp/PetImages/Cat/cat.2359.jpg
# /tmp/PetImages/Cat/cat.2.jpg
# /tmp/PetImages/Cat/cat.809.jpg
# /tmp/PetImages/Cat/cat.145.jpg
# /tmp/PetImages/Cat/cat.956.jpg
# /tmp/PetImages/Cat/cat.524.jpg
# /tmp/PetImages/Cat/cat.283.jpg
# /tmp/PetImages/Cat/cat.2206.jpg
# /tmp/PetImages/Cat/cat.987.jpg
# /tmp/PetImages/Cat/cat.252.jpg
# /tmp/PetImages/Cat/cat.2111.jpg
# /tmp/PetImages/Cat/cat.194.jpg
# /tmp/PetImages/Cat/cat.633.jpg
# /tmp/PetImages/Cat/cat.12.jpg
# /tmp/PetImages/Cat/cat.2428.jpg
# /tmp/PetImages/Cat/cat.2049.jpg
# /tmp/PetImages/Cat/cat.2098.jpg
# /tmp/PetImages/Cat/cat.5.jpg
# /tmp/PetImages/Cat/cat.139.jpg
# /tmp/PetImages/Cat/cat.558.jpg
# /tmp/PetImages/Cat/cat.589.jpg
# /tmp/PetImages/Cat/cat.2454.jpg
# /tmp/PetImages/Cat/cat.376.jpg
# /tmp/PetImages/Cat/cat.2035.jpg
# /tmp/PetImages/Cat/cat.717.jpg
# /tmp/PetImages/Cat/cat.400.jpg
# /tmp/PetImages/Cat/cat.872.jpg
# /tmp/PetImages/Cat/cat.2485.jpg
# /tmp/PetImages/Cat/cat.2322.jpg
# /tmp/PetImages/Cat/cat.2208.jpg
# /tmp/PetImages/Cat/cat.958.jpg
# /tmp/PetImages/Cat/cat.989.jpg
# /tmp/PetImages/Cat/cat.2381.jpg
# /tmp/PetImages/Cat/cat.2426.jpg
# /tmp/PetImages/Cat/cat.304.jpg
# /tmp/PetImages/Cat/cat.2047.jpg
# /tmp/PetImages/Cat/cat.765.jpg
# /tmp/PetImages/Cat/cat.2096.jpg
# /tmp/PetImages/Cat/cat.472.jpg
# /tmp/PetImages/Cat/cat.800.jpg
# /tmp/PetImages/Cat/cat.2350.jpg
# /tmp/PetImages/Cat/cat.690.jpg
# /tmp/PetImages/Cat/cat.137.jpg
# /tmp/PetImages/Cat/cat.924.jpg
# /tmp/PetImages/Cat/cat.556.jpg
# /tmp/PetImages/Cat/cat.2274.jpg
# /tmp/PetImages/Cat/cat.220.jpg
# /tmp/PetImages/Cat/cat.587.jpg
# /tmp/PetImages/Cat/cat.2163.jpg
# /tmp/PetImages/Cat/cat.60.jpg
# /tmp/PetImages/Cat/cat.641.jpg
# /tmp/PetImages/Cat/cat.378.jpg
# /tmp/PetImages/Cat/cat.719.jpg
# /tmp/PetImages/Cat/cat.130.jpg
# /tmp/PetImages/Cat/cat.697.jpg
# /tmp/PetImages/Cat/cat.551.jpg
# /tmp/PetImages/Cat/cat.923.jpg
# /tmp/PetImages/Cat/cat.2273.jpg
# /tmp/PetImages/Cat/cat.580.jpg
# /tmp/PetImages/Cat/cat.227.jpg
# /tmp/PetImages/Cat/cat.2164.jpg
# /tmp/PetImages/Cat/cat.646.jpg
# /tmp/PetImages/Cat/cat.67.jpg
# /tmp/PetImages/Cat/cat.409.jpg
# /tmp/PetImages/Cat/cat.2118.jpg
# /tmp/PetImages/Cat/cat.2421.jpg
# /tmp/PetImages/Cat/cat.2386.jpg
# /tmp/PetImages/Cat/cat.303.jpg
# /tmp/PetImages/Cat/cat.2040.jpg
# /tmp/PetImages/Cat/cat.762.jpg
# /tmp/PetImages/Cat/cat.2091.jpg
# /tmp/PetImages/Cat/cat.807.jpg
# /tmp/PetImages/Cat/cat.475.jpg
# /tmp/PetImages/Cat/cat.2357.jpg
# /tmp/PetImages/Cat/cat.2151.jpg
# /tmp/PetImages/Cat/cat.673.jpg
# /tmp/PetImages/Cat/cat.52.jpg
# /tmp/PetImages/Cat/cat.2297.jpg
# /tmp/PetImages/Cat/cat.212.jpg
# /tmp/PetImages/Cat/cat.564.jpg
# /tmp/PetImages/Cat/cat.916.jpg
# /tmp/PetImages/Cat/cat.2246.jpg
# /tmp/PetImages/Cat/cat.83.jpg
# /tmp/PetImages/Cat/cat.105.jpg
# /tmp/PetImages/Cat/cat.2180.jpg
# /tmp/PetImages/Cat/cat.2009.jpg
# /tmp/PetImages/Cat/cat.2468.jpg
# /tmp/PetImages/Cat/cat.518.jpg
# /tmp/PetImages/Cat/cat.179.jpg
# /tmp/PetImages/Cat/cat.832.jpg
# /tmp/PetImages/Cat/cat.440.jpg
# /tmp/PetImages/Cat/cat.2362.jpg
# /tmp/PetImages/Cat/cat.786.jpg
# /tmp/PetImages/Cat/cat.2075.jpg
# /tmp/PetImages/Cat/cat.757.jpg
# /tmp/PetImages/Cat/cat.2414.jpg
# /tmp/PetImages/Cat/cat.491.jpg
# /tmp/PetImages/Cat/cat.336.jpg
# /tmp/PetImages/Cat/cat.29.jpg
# /tmp/PetImages/Cat/cat.608.jpg
# /tmp/PetImages/Cat/cat.269.jpg
# /tmp/PetImages/Cat/cat.447.jpg
# /tmp/PetImages/Cat/cat.835.jpg
# /tmp/PetImages/Cat/cat.2365.jpg
# /tmp/PetImages/Cat/cat.781.jpg
# /tmp/PetImages/Cat/cat.2072.jpg
# /tmp/PetImages/Cat/cat.750.jpg
# /tmp/PetImages/Cat/cat.2413.jpg
# /tmp/PetImages/Cat/cat.331.jpg
# /tmp/PetImages/Cat/cat.496.jpg
# /tmp/PetImages/Cat/cat.2156.jpg
# /tmp/PetImages/Cat/cat.55.jpg
# /tmp/PetImages/Cat/cat.674.jpg
# /tmp/PetImages/Cat/cat.2290.jpg
# /tmp/PetImages/Cat/cat.215.jpg
# /tmp/PetImages/Cat/cat.911.jpg
# /tmp/PetImages/Cat/cat.563.jpg
# /tmp/PetImages/Cat/cat.2241.jpg
# /tmp/PetImages/Cat/cat.102.jpg
# /tmp/PetImages/Cat/cat.84.jpg
# /tmp/PetImages/Cat/cat.2187.jpg
# /tmp/PetImages/Cat/cat.2319.jpg
# /tmp/PetImages/Cat/cat.849.jpg
# /tmp/PetImages/Cat/cat.898.jpg
# /tmp/PetImages/Cat/cat.2124.jpg
# /tmp/PetImages/Cat/cat.606.jpg
# /tmp/PetImages/Cat/cat.27.jpg
# /tmp/PetImages/Cat/cat.267.jpg
# /tmp/PetImages/Cat/cat.963.jpg
# /tmp/PetImages/Cat/cat.511.jpg
# /tmp/PetImages/Cat/cat.2233.jpg
# /tmp/PetImages/Cat/cat.170.jpg
# /tmp/PetImages/Cat/cat.449.jpg
# /tmp/PetImages/Cat/cat.498.jpg
# /tmp/PetImages/Cat/cat.2158.jpg
# /tmp/PetImages/Cat/cat.2189.jpg
# /tmp/PetImages/Cat/cat.435.jpg
# /tmp/PetImages/Cat/cat.847.jpg
# /tmp/PetImages/Cat/cat.392.jpg
# /tmp/PetImages/Cat/cat.2317.jpg
# /tmp/PetImages/Cat/cat.2000.jpg
# /tmp/PetImages/Cat/cat.722.jpg
# /tmp/PetImages/Cat/cat.2461.jpg
# /tmp/PetImages/Cat/cat.896.jpg
# /tmp/PetImages/Cat/cat.343.jpg
# /tmp/PetImages/Cat/cat.2299.jpg
# /tmp/PetImages/Cat/cat.2248.jpg
# /tmp/PetImages/Cat/cat.918.jpg
# /tmp/PetImages/Cat/cat.395.jpg
# /tmp/PetImages/Cat/cat.840.jpg
# /tmp/PetImages/Cat/cat.432.jpg
# /tmp/PetImages/Cat/cat.2310.jpg
# /tmp/PetImages/Cat/cat.2007.jpg
# /tmp/PetImages/Cat/cat.725.jpg
# /tmp/PetImages/Cat/cat.2466.jpg
# /tmp/PetImages/Cat/cat.344.jpg
# /tmp/PetImages/Cat/cat.891.jpg
# /tmp/PetImages/Cat/cat.2123.jpg
# /tmp/PetImages/Cat/cat.20.jpg
# /tmp/PetImages/Cat/cat.601.jpg
# /tmp/PetImages/Cat/cat.260.jpg
# /tmp/PetImages/Cat/cat.516.jpg
# /tmp/PetImages/Cat/cat.964.jpg
# /tmp/PetImages/Cat/cat.2234.jpg
# /tmp/PetImages/Cat/cat.177.jpg
# /tmp/PetImages/Cat/cat.788.jpg
# /tmp/PetImages/Cat/cat.759.jpg
# /tmp/PetImages/Cat/cat.338.jpg
# /tmp/PetImages/Cat/cat.734.jpg
# /tmp/PetImages/Cat/cat.2016.jpg
# /tmp/PetImages/Cat/cat.880.jpg
# /tmp/PetImages/Cat/cat.355.jpg
# /tmp/PetImages/Cat/cat.2477.jpg
# /tmp/PetImages/Cat/cat.2301.jpg
# /tmp/PetImages/Cat/cat.423.jpg
# /tmp/PetImages/Cat/cat.851.jpg
# /tmp/PetImages/Cat/cat.384.jpg
# /tmp/PetImages/Cat/cat.909.jpg
# /tmp/PetImages/Cat/cat.2259.jpg
# /tmp/PetImages/Cat/cat.2288.jpg
# /tmp/PetImages/Cat/cat.748.jpg
# /tmp/PetImages/Cat/cat.329.jpg
# /tmp/PetImages/Cat/cat.799.jpg
# /tmp/PetImages/Cat/cat.2225.jpg
# /tmp/PetImages/Cat/cat.975.jpg
# /tmp/PetImages/Cat/cat.507.jpg
# /tmp/PetImages/Cat/cat.166.jpg
# /tmp/PetImages/Cat/cat.31.jpg
# /tmp/PetImages/Cat/cat.610.jpg
# /tmp/PetImages/Cat/cat.2132.jpg
# /tmp/PetImages/Cat/cat.271.jpg
# /tmp/PetImages/Cat/cat.489.jpg
# /tmp/PetImages/Cat/cat.458.jpg
# /tmp/PetImages/Cat/cat.2222.jpg
# /tmp/PetImages/Cat/cat.500.jpg
# /tmp/PetImages/Cat/cat.972.jpg
# /tmp/PetImages/Cat/cat.161.jpg
# /tmp/PetImages/Cat/cat.617.jpg
# /tmp/PetImages/Cat/cat.36.jpg
# /tmp/PetImages/Cat/cat.2135.jpg
# /tmp/PetImages/Cat/cat.276.jpg
# /tmp/PetImages/Cat/cat.733.jpg
# /tmp/PetImages/Cat/cat.2011.jpg
# /tmp/PetImages/Cat/cat.352.jpg
# /tmp/PetImages/Cat/cat.887.jpg
# /tmp/PetImages/Cat/cat.2470.jpg
# /tmp/PetImages/Cat/cat.2306.jpg
# /tmp/PetImages/Cat/cat.383.jpg
# /tmp/PetImages/Cat/cat.856.jpg
# /tmp/PetImages/Cat/cat.424.jpg
# /tmp/PetImages/Cat/cat.2198.jpg
# /tmp/PetImages/Cat/cat.2149.jpg
# /tmp/PetImages/Cat/cat.741.jpg
# /tmp/PetImages/Cat/cat.2063.jpg
# /tmp/PetImages/Cat/cat.487.jpg
# /tmp/PetImages/Cat/cat.320.jpg
# /tmp/PetImages/Cat/cat.2402.jpg
# /tmp/PetImages/Cat/cat.2374.jpg
# /tmp/PetImages/Cat/cat.824.jpg
# /tmp/PetImages/Cat/cat.456.jpg
# /tmp/PetImages/Cat/cat.790.jpg
# /tmp/PetImages/Cat/cat.38.jpg
# /tmp/PetImages/Cat/cat.619.jpg
# /tmp/PetImages/Cat/cat.278.jpg
# /tmp/PetImages/Cat/cat.889.jpg
# /tmp/PetImages/Cat/cat.858.jpg
# /tmp/PetImages/Cat/cat.2308.jpg
# /tmp/PetImages/Cat/cat.2250.jpg
# /tmp/PetImages/Cat/cat.572.jpg
# /tmp/PetImages/Cat/cat.900.jpg
# /tmp/PetImages/Cat/cat.2196.jpg
# /tmp/PetImages/Cat/cat.113.jpg
# /tmp/PetImages/Cat/cat.95.jpg
# /tmp/PetImages/Cat/cat.44.jpg
# /tmp/PetImages/Cat/cat.665.jpg
# /tmp/PetImages/Cat/cat.2147.jpg
# /tmp/PetImages/Cat/cat.204.jpg
# /tmp/PetImages/Cat/cat.2281.jpg
# /tmp/PetImages/Cat/cat.2018.jpg
# /tmp/PetImages/Cat/cat.2479.jpg
# /tmp/PetImages/Cat/cat.2257.jpg
# /tmp/PetImages/Cat/cat.907.jpg
# /tmp/PetImages/Cat/cat.575.jpg
# /tmp/PetImages/Cat/cat.2191.jpg
# /tmp/PetImages/Cat/cat.92.jpg
# /tmp/PetImages/Cat/cat.114.jpg
# /tmp/PetImages/Cat/cat.662.jpg
# /tmp/PetImages/Cat/cat.43.jpg
# /tmp/PetImages/Cat/cat.2140.jpg
# /tmp/PetImages/Cat/cat.203.jpg
# /tmp/PetImages/Cat/cat.2286.jpg
# /tmp/PetImages/Cat/cat.746.jpg
# /tmp/PetImages/Cat/cat.2064.jpg
# /tmp/PetImages/Cat/cat.327.jpg
# /tmp/PetImages/Cat/cat.480.jpg
# /tmp/PetImages/Cat/cat.2405.jpg
# /tmp/PetImages/Cat/cat.2373.jpg
# /tmp/PetImages/Cat/cat.451.jpg
# /tmp/PetImages/Cat/cat.823.jpg
# /tmp/PetImages/Cat/cat.797.jpg
# /tmp/PetImages/Cat/cat.509.jpg
# /tmp/PetImages/Cat/cat.168.jpg
# /tmp/PetImages/Cat/cat.418.jpg
# /tmp/PetImages/Cat/cat.236.jpg
# /tmp/PetImages/Cat/cat.591.jpg
# /tmp/PetImages/Cat/cat.657.jpg
# /tmp/PetImages/Cat/cat.76.jpg
# /tmp/PetImages/Cat/cat.2175.jpg
# /tmp/PetImages/Cat/cat.686.jpg
# /tmp/PetImages/Cat/cat.121.jpg
# /tmp/PetImages/Cat/cat.2262.jpg
# /tmp/PetImages/Cat/cat.932.jpg
# /tmp/PetImages/Cat/cat.540.jpg
# /tmp/PetImages/Cat/cat.2080.jpg
# /tmp/PetImages/Cat/cat.2346.jpg
# /tmp/PetImages/Cat/cat.464.jpg
# /tmp/PetImages/Cat/cat.816.jpg
# /tmp/PetImages/Cat/cat.312.jpg
# /tmp/PetImages/Cat/cat.2397.jpg
# /tmp/PetImages/Cat/cat.2430.jpg
# /tmp/PetImages/Cat/cat.773.jpg
# /tmp/PetImages/Cat/cat.2051.jpg
# /tmp/PetImages/Cat/cat.2109.jpg
# /tmp/PetImages/Cat/cat.2087.jpg
# /tmp/PetImages/Cat/cat.2341.jpg
# /tmp/PetImages/Cat/cat.811.jpg
# /tmp/PetImages/Cat/cat.463.jpg
# /tmp/PetImages/Cat/cat.315.jpg
# /tmp/PetImages/Cat/cat.2437.jpg
# /tmp/PetImages/Cat/cat.2390.jpg
# /tmp/PetImages/Cat/cat.774.jpg
# /tmp/PetImages/Cat/cat.2056.jpg
# /tmp/PetImages/Cat/cat.998.jpg
# /tmp/PetImages/Cat/cat.949.jpg
# /tmp/PetImages/Cat/cat.2219.jpg
# /tmp/PetImages/Cat/cat.369.jpg
# /tmp/PetImages/Cat/cat.708.jpg
# /tmp/PetImages/Cat/cat.596.jpg
# /tmp/PetImages/Cat/cat.231.jpg
# /tmp/PetImages/Cat/cat.71.jpg
# /tmp/PetImages/Cat/cat.650.jpg
# /tmp/PetImages/Cat/cat.2172.jpg
# /tmp/PetImages/Cat/cat.126.jpg
# /tmp/PetImages/Cat/cat.681.jpg
# /tmp/PetImages/Cat/cat.2265.jpg
# /tmp/PetImages/Cat/cat.547.jpg
# /tmp/PetImages/Cat/cat.935.jpg
# /tmp/PetImages/Cat/cat.2089.jpg
# /tmp/PetImages/Cat/cat.2439.jpg
# /tmp/PetImages/Cat/cat.2058.jpg
# /tmp/PetImages/Cat/cat.243.jpg
# /tmp/PetImages/Cat/cat.996.jpg
# /tmp/PetImages/Cat/cat.622.jpg
# /tmp/PetImages/Cat/cat.185.jpg
# /tmp/PetImages/Cat/cat.2100.jpg
# /tmp/PetImages/Cat/cat.154.jpg
# /tmp/PetImages/Cat/cat.2217.jpg
# /tmp/PetImages/Cat/cat.292.jpg
# /tmp/PetImages/Cat/cat.535.jpg
# /tmp/PetImages/Cat/cat.947.jpg
# /tmp/PetImages/Cat/cat.2333.jpg
# /tmp/PetImages/Cat/cat.2494.jpg
# /tmp/PetImages/Cat/cat.863.jpg
# /tmp/PetImages/Cat/cat.411.jpg
# /tmp/PetImages/Cat/cat.367.jpg
# /tmp/PetImages/Cat/cat.2445.jpg
# /tmp/PetImages/Cat/cat.706.jpg
# /tmp/PetImages/Cat/cat.2024.jpg
# /tmp/PetImages/Cat/cat.598.jpg
# /tmp/PetImages/Cat/cat.128.jpg
# /tmp/PetImages/Cat/cat.549.jpg
# /tmp/PetImages/Cat/cat.2493.jpg
# /tmp/PetImages/Cat/cat.2334.jpg
# /tmp/PetImages/Cat/cat.416.jpg
# /tmp/PetImages/Cat/cat.864.jpg
# /tmp/PetImages/Cat/cat.360.jpg
# /tmp/PetImages/Cat/cat.2442.jpg
# /tmp/PetImages/Cat/cat.701.jpg
# /tmp/PetImages/Cat/cat.2023.jpg
# /tmp/PetImages/Cat/cat.238.jpg
# /tmp/PetImages/Cat/cat.78.jpg
# /tmp/PetImages/Cat/cat.659.jpg
# /tmp/PetImages/Cat/cat.688.jpg
# /tmp/PetImages/Cat/cat.818.jpg
# /tmp/PetImages/Cat/cat.2348.jpg
# /tmp/PetImages/Cat/cat.2399.jpg
# /tmp/PetImages/Cat/cat.991.jpg
# /tmp/PetImages/Cat/cat.244.jpg
# /tmp/PetImages/Cat/cat.182.jpg
# /tmp/PetImages/Cat/cat.625.jpg
# /tmp/PetImages/Cat/cat.2107.jpg
# /tmp/PetImages/Cat/cat.153.jpg
# /tmp/PetImages/Cat/cat.2210.jpg
# /tmp/PetImages/Cat/cat.940.jpg
# /tmp/PetImages/Cat/cat.532.jpg
# /tmp/PetImages/Cat/cat.295.jpg
# /tmp/PetImages/Cat/cat.2298.jpg
# /tmp/PetImages/Cat/cat.919.jpg
# /tmp/PetImages/Cat/cat.2249.jpg
# /tmp/PetImages/Cat/cat.2311.jpg
# /tmp/PetImages/Cat/cat.841.jpg
# /tmp/PetImages/Cat/cat.433.jpg
# /tmp/PetImages/Cat/cat.394.jpg
# /tmp/PetImages/Cat/cat.724.jpg
# /tmp/PetImages/Cat/cat.2006.jpg
# /tmp/PetImages/Cat/cat.890.jpg
# /tmp/PetImages/Cat/cat.345.jpg
# /tmp/PetImages/Cat/cat.2467.jpg
# /tmp/PetImages/Cat/cat.21.jpg
# /tmp/PetImages/Cat/cat.600.jpg
# /tmp/PetImages/Cat/cat.2122.jpg
# /tmp/PetImages/Cat/cat.261.jpg
# /tmp/PetImages/Cat/cat.2235.jpg
# /tmp/PetImages/Cat/cat.517.jpg
# /tmp/PetImages/Cat/cat.965.jpg
# /tmp/PetImages/Cat/cat.176.jpg
# /tmp/PetImages/Cat/cat.789.jpg
# /tmp/PetImages/Cat/cat.758.jpg
# /tmp/PetImages/Cat/cat.339.jpg
# /tmp/PetImages/Cat/cat.607.jpg
# /tmp/PetImages/Cat/cat.26.jpg
# /tmp/PetImages/Cat/cat.2125.jpg
# /tmp/PetImages/Cat/cat.266.jpg
# /tmp/PetImages/Cat/cat.2232.jpg
# /tmp/PetImages/Cat/cat.962.jpg
# /tmp/PetImages/Cat/cat.510.jpg
# /tmp/PetImages/Cat/cat.171.jpg
# /tmp/PetImages/Cat/cat.448.jpg
# /tmp/PetImages/Cat/cat.499.jpg
# /tmp/PetImages/Cat/cat.2159.jpg
# /tmp/PetImages/Cat/cat.2188.jpg
# /tmp/PetImages/Cat/cat.2316.jpg
# /tmp/PetImages/Cat/cat.393.jpg
# /tmp/PetImages/Cat/cat.434.jpg
# /tmp/PetImages/Cat/cat.846.jpg
# /tmp/PetImages/Cat/cat.723.jpg
# /tmp/PetImages/Cat/cat.2001.jpg
# /tmp/PetImages/Cat/cat.342.jpg
# /tmp/PetImages/Cat/cat.897.jpg
# /tmp/PetImages/Cat/cat.2460.jpg
# /tmp/PetImages/Cat/cat.28.jpg
# /tmp/PetImages/Cat/cat.609.jpg
# /tmp/PetImages/Cat/cat.268.jpg
# /tmp/PetImages/Cat/cat.2364.jpg
# /tmp/PetImages/Cat/cat.446.jpg
# /tmp/PetImages/Cat/cat.834.jpg
# /tmp/PetImages/Cat/cat.780.jpg
# /tmp/PetImages/Cat/cat.751.jpg
# /tmp/PetImages/Cat/cat.2073.jpg
# /tmp/PetImages/Cat/cat.497.jpg
# /tmp/PetImages/Cat/cat.330.jpg
# /tmp/PetImages/Cat/cat.2412.jpg
# /tmp/PetImages/Cat/cat.54.jpg
# /tmp/PetImages/Cat/cat.675.jpg
# /tmp/PetImages/Cat/cat.2157.jpg
# /tmp/PetImages/Cat/cat.214.jpg
# /tmp/PetImages/Cat/cat.2291.jpg
# /tmp/PetImages/Cat/cat.2240.jpg
# /tmp/PetImages/Cat/cat.910.jpg
# /tmp/PetImages/Cat/cat.562.jpg
# /tmp/PetImages/Cat/cat.2186.jpg
# /tmp/PetImages/Cat/cat.103.jpg
# /tmp/PetImages/Cat/cat.85.jpg
# /tmp/PetImages/Cat/cat.848.jpg
# /tmp/PetImages/Cat/cat.2318.jpg
# /tmp/PetImages/Cat/cat.899.jpg
# /tmp/PetImages/Cat/cat.672.jpg
# /tmp/PetImages/Cat/cat.53.jpg
# /tmp/PetImages/Cat/cat.2150.jpg
# /tmp/PetImages/Cat/cat.213.jpg
# /tmp/PetImages/Cat/cat.2296.jpg
# /tmp/PetImages/Cat/cat.2247.jpg
# /tmp/PetImages/Cat/cat.565.jpg
# /tmp/PetImages/Cat/cat.917.jpg
# /tmp/PetImages/Cat/cat.2181.jpg
# /tmp/PetImages/Cat/cat.82.jpg
# /tmp/PetImages/Cat/cat.104.jpg
# /tmp/PetImages/Cat/cat.2008.jpg
# /tmp/PetImages/Cat/cat.2469.jpg
# /tmp/PetImages/Cat/cat.519.jpg
# /tmp/PetImages/Cat/cat.178.jpg
# /tmp/PetImages/Cat/cat.2363.jpg
# /tmp/PetImages/Cat/cat.833.jpg
# /tmp/PetImages/Cat/cat.441.jpg
# /tmp/PetImages/Cat/cat.787.jpg
# /tmp/PetImages/Cat/cat.756.jpg
# /tmp/PetImages/Cat/cat.2074.jpg
# /tmp/PetImages/Cat/cat.337.jpg
# /tmp/PetImages/Cat/cat.490.jpg
# /tmp/PetImages/Cat/cat.2415.jpg
# /tmp/PetImages/Cat/cat.696.jpg
# /tmp/PetImages/Cat/cat.131.jpg
# /tmp/PetImages/Cat/cat.2272.jpg
# /tmp/PetImages/Cat/cat.550.jpg
# /tmp/PetImages/Cat/cat.922.jpg
# /tmp/PetImages/Cat/cat.226.jpg
# /tmp/PetImages/Cat/cat.581.jpg
# /tmp/PetImages/Cat/cat.647.jpg
# /tmp/PetImages/Cat/cat.66.jpg
# /tmp/PetImages/Cat/cat.2165.jpg
# /tmp/PetImages/Cat/cat.408.jpg
# /tmp/PetImages/Cat/cat.2119.jpg
# /tmp/PetImages/Cat/cat.302.jpg
# /tmp/PetImages/Cat/cat.2387.jpg
# /tmp/PetImages/Cat/cat.2420.jpg
# /tmp/PetImages/Cat/cat.763.jpg
# /tmp/PetImages/Cat/cat.2041.jpg
# /tmp/PetImages/Cat/cat.2090.jpg
# /tmp/PetImages/Cat/cat.2356.jpg
# /tmp/PetImages/Cat/cat.806.jpg
# /tmp/PetImages/Cat/cat.474.jpg
# /tmp/PetImages/Cat/cat.959.jpg
# /tmp/PetImages/Cat/cat.2209.jpg
# /tmp/PetImages/Cat/cat.988.jpg
# /tmp/PetImages/Cat/cat.305.jpg
# /tmp/PetImages/Cat/cat.2427.jpg
# /tmp/PetImages/Cat/cat.2380.jpg
# /tmp/PetImages/Cat/cat.764.jpg
# /tmp/PetImages/Cat/cat.2046.jpg
# /tmp/PetImages/Cat/cat.2097.jpg
# /tmp/PetImages/Cat/cat.2351.jpg
# /tmp/PetImages/Cat/cat.473.jpg
# /tmp/PetImages/Cat/cat.801.jpg
# /tmp/PetImages/Cat/cat.136.jpg
# /tmp/PetImages/Cat/cat.691.jpg
# /tmp/PetImages/Cat/cat.2275.jpg
# /tmp/PetImages/Cat/cat.925.jpg
# /tmp/PetImages/Cat/cat.557.jpg
# /tmp/PetImages/Cat/cat.586.jpg
# /tmp/PetImages/Cat/cat.221.jpg
# /tmp/PetImages/Cat/cat.61.jpg
# /tmp/PetImages/Cat/cat.640.jpg
# /tmp/PetImages/Cat/cat.2162.jpg
# /tmp/PetImages/Cat/cat.379.jpg
# /tmp/PetImages/Cat/cat.718.jpg
# /tmp/PetImages/Cat/cat.144.jpg
# /tmp/PetImages/Cat/cat.2207.jpg
# /tmp/PetImages/Cat/cat.282.jpg
# /tmp/PetImages/Cat/cat.957.jpg
# /tmp/PetImages/Cat/cat.525.jpg
# /tmp/PetImages/Cat/cat.253.jpg
# /tmp/PetImages/Cat/cat.986.jpg
# /tmp/PetImages/Cat/cat.632.jpg
# /tmp/PetImages/Cat/cat.195.jpg
# /tmp/PetImages/Cat/cat.13.jpg
# /tmp/PetImages/Cat/cat.2110.jpg
# /tmp/PetImages/Cat/cat.2429.jpg
# /tmp/PetImages/Cat/cat.2048.jpg
# /tmp/PetImages/Cat/cat.2099.jpg
# /tmp/PetImages/Cat/cat.4.jpg
# /tmp/PetImages/Cat/cat.138.jpg
# /tmp/PetImages/Cat/cat.559.jpg
# /tmp/PetImages/Cat/cat.588.jpg
# /tmp/PetImages/Cat/cat.377.jpg
# /tmp/PetImages/Cat/cat.2455.jpg
# /tmp/PetImages/Cat/cat.716.jpg
# /tmp/PetImages/Cat/cat.2034.jpg
# /tmp/PetImages/Cat/cat.2323.jpg
# /tmp/PetImages/Cat/cat.2484.jpg
# /tmp/PetImages/Cat/cat.401.jpg
# /tmp/PetImages/Cat/cat.873.jpg
# /tmp/PetImages/Cat/cat.698.jpg
# /tmp/PetImages/Cat/cat.228.jpg
# /tmp/PetImages/Cat/cat.68.jpg
# /tmp/PetImages/Cat/cat.649.jpg
# /tmp/PetImages/Cat/cat.370.jpg
# /tmp/PetImages/Cat/cat.2452.jpg
# /tmp/PetImages/Cat/cat.711.jpg
# /tmp/PetImages/Cat/cat.2033.jpg
# /tmp/PetImages/Cat/cat.2483.jpg
# /tmp/PetImages/Cat/cat.2324.jpg
# /tmp/PetImages/Cat/cat.874.jpg
# /tmp/PetImages/Cat/cat.406.jpg
# /tmp/PetImages/Cat/cat.143.jpg
# /tmp/PetImages/Cat/cat.2200.jpg
# /tmp/PetImages/Cat/cat.522.jpg
# /tmp/PetImages/Cat/cat.950.jpg
# /tmp/PetImages/Cat/cat.285.jpg
# /tmp/PetImages/Cat/cat.981.jpg
# /tmp/PetImages/Cat/cat.254.jpg
# /tmp/PetImages/Cat/cat.14.jpg
# /tmp/PetImages/Cat/cat.192.jpg
# /tmp/PetImages/Cat/cat.635.jpg
# /tmp/PetImages/Cat/cat.2117.jpg
# /tmp/PetImages/Cat/cat.2389.jpg
# /tmp/PetImages/Cat/cat.3.jpg
# /tmp/PetImages/Cat/cat.808.jpg
# /tmp/PetImages/Cat/cat.2358.jpg
# /tmp/PetImages/Cat/cat.417.jpg
# /tmp/PetImages/Cat/cat.865.jpg
# /tmp/PetImages/Cat/cat.2335.jpg
# /tmp/PetImages/Cat/cat.2492.jpg
# /tmp/PetImages/Cat/cat.2443.jpg
# /tmp/PetImages/Cat/cat.361.jpg
# /tmp/PetImages/Cat/cat.2022.jpg
# /tmp/PetImages/Cat/cat.700.jpg
# /tmp/PetImages/Cat/cat.239.jpg
# /tmp/PetImages/Cat/cat.79.jpg
# /tmp/PetImages/Cat/cat.658.jpg
# /tmp/PetImages/Cat/cat.689.jpg
# /tmp/PetImages/Cat/cat.2349.jpg
# /tmp/PetImages/Cat/cat.819.jpg
# /tmp/PetImages/Cat/cat.2398.jpg
# /tmp/PetImages/Cat/cat.245.jpg
# /tmp/PetImages/Cat/cat.990.jpg
# /tmp/PetImages/Cat/cat.2106.jpg
# /tmp/PetImages/Cat/cat.624.jpg
# /tmp/PetImages/Cat/cat.183.jpg
# /tmp/PetImages/Cat/cat.152.jpg
# /tmp/PetImages/Cat/cat.294.jpg
# /tmp/PetImages/Cat/cat.941.jpg
# /tmp/PetImages/Cat/cat.533.jpg
# /tmp/PetImages/Cat/cat.2211.jpg
# /tmp/PetImages/Cat/cat.2088.jpg
# /tmp/PetImages/Cat/cat.2438.jpg
# /tmp/PetImages/Cat/cat.2059.jpg
# /tmp/PetImages/Cat/cat.997.jpg
# /tmp/PetImages/Cat/cat.242.jpg
# /tmp/PetImages/Cat/cat.2101.jpg
# /tmp/PetImages/Cat/cat.184.jpg
# /tmp/PetImages/Cat/cat.623.jpg
# /tmp/PetImages/Cat/cat.155.jpg
# /tmp/PetImages/Cat/cat.534.jpg
# /tmp/PetImages/Cat/cat.946.jpg
# /tmp/PetImages/Cat/cat.293.jpg
# /tmp/PetImages/Cat/cat.2216.jpg
# /tmp/PetImages/Cat/cat.862.jpg
# /tmp/PetImages/Cat/cat.410.jpg
# /tmp/PetImages/Cat/cat.2495.jpg
# /tmp/PetImages/Cat/cat.2332.jpg
# /tmp/PetImages/Cat/cat.2444.jpg
# /tmp/PetImages/Cat/cat.366.jpg
# /tmp/PetImages/Cat/cat.2025.jpg
# /tmp/PetImages/Cat/cat.707.jpg
# /tmp/PetImages/Cat/cat.599.jpg
# /tmp/PetImages/Cat/cat.129.jpg
# /tmp/PetImages/Cat/cat.548.jpg
# /tmp/PetImages/Cat/cat.2086.jpg
# /tmp/PetImages/Cat/cat.810.jpg
# /tmp/PetImages/Cat/cat.462.jpg
# /tmp/PetImages/Cat/cat.2340.jpg
# /tmp/PetImages/Cat/cat.2391.jpg
# /tmp/PetImages/Cat/cat.2436.jpg
# /tmp/PetImages/Cat/cat.314.jpg
# /tmp/PetImages/Cat/cat.2057.jpg
# /tmp/PetImages/Cat/cat.775.jpg
# /tmp/PetImages/Cat/cat.999.jpg
# /tmp/PetImages/Cat/cat.2218.jpg
# /tmp/PetImages/Cat/cat.948.jpg
# /tmp/PetImages/Cat/cat.368.jpg
# /tmp/PetImages/Cat/cat.709.jpg
# /tmp/PetImages/Cat/cat.230.jpg
# /tmp/PetImages/Cat/cat.597.jpg
# /tmp/PetImages/Cat/cat.2173.jpg
# /tmp/PetImages/Cat/cat.70.jpg
# /tmp/PetImages/Cat/cat.651.jpg
# /tmp/PetImages/Cat/cat.680.jpg
# /tmp/PetImages/Cat/cat.127.jpg
# /tmp/PetImages/Cat/cat.546.jpg
# /tmp/PetImages/Cat/cat.934.jpg
# /tmp/PetImages/Cat/cat.2264.jpg
# /tmp/PetImages/Cat/cat.419.jpg
# /tmp/PetImages/Cat/cat.590.jpg
# /tmp/PetImages/Cat/cat.237.jpg
# /tmp/PetImages/Cat/cat.2174.jpg
# /tmp/PetImages/Cat/cat.656.jpg
# /tmp/PetImages/Cat/cat.77.jpg
# /tmp/PetImages/Cat/cat.120.jpg
# /tmp/PetImages/Cat/cat.687.jpg
# /tmp/PetImages/Cat/cat.933.jpg
# /tmp/PetImages/Cat/cat.541.jpg
# /tmp/PetImages/Cat/cat.2263.jpg
# /tmp/PetImages/Cat/cat.2081.jpg
# /tmp/PetImages/Cat/cat.465.jpg
# /tmp/PetImages/Cat/cat.817.jpg
# /tmp/PetImages/Cat/cat.2347.jpg
# /tmp/PetImages/Cat/cat.2431.jpg
# /tmp/PetImages/Cat/cat.2396.jpg
# /tmp/PetImages/Cat/cat.313.jpg
# /tmp/PetImages/Cat/cat.2050.jpg
# /tmp/PetImages/Cat/cat.772.jpg
# /tmp/PetImages/Cat/cat.2108.jpg
# /tmp/PetImages/Cat/cat.2019.jpg
# /tmp/PetImages/Cat/cat.2478.jpg
# /tmp/PetImages/Cat/cat.906.jpg
# /tmp/PetImages/Cat/cat.574.jpg
# /tmp/PetImages/Cat/cat.2256.jpg
# /tmp/PetImages/Cat/cat.93.jpg
# /tmp/PetImages/Cat/cat.115.jpg
# /tmp/PetImages/Cat/cat.2190.jpg
# /tmp/PetImages/Cat/cat.2141.jpg
# /tmp/PetImages/Cat/cat.663.jpg
# /tmp/PetImages/Cat/cat.42.jpg
# /tmp/PetImages/Cat/cat.2287.jpg
# /tmp/PetImages/Cat/cat.202.jpg
# /tmp/PetImages/Cat/cat.2065.jpg
# /tmp/PetImages/Cat/cat.747.jpg
# /tmp/PetImages/Cat/cat.2404.jpg
# /tmp/PetImages/Cat/cat.481.jpg
# /tmp/PetImages/Cat/cat.326.jpg
# /tmp/PetImages/Cat/cat.450.jpg
# /tmp/PetImages/Cat/cat.822.jpg
# /tmp/PetImages/Cat/cat.2372.jpg
# /tmp/PetImages/Cat/cat.796.jpg
# /tmp/PetImages/Cat/cat.508.jpg
# /tmp/PetImages/Cat/cat.169.jpg
# /tmp/PetImages/Cat/cat.2062.jpg
# /tmp/PetImages/Cat/cat.740.jpg
# /tmp/PetImages/Cat/cat.2403.jpg
# /tmp/PetImages/Cat/cat.321.jpg
# /tmp/PetImages/Cat/cat.486.jpg
# /tmp/PetImages/Cat/cat.825.jpg
# /tmp/PetImages/Cat/cat.457.jpg
# /tmp/PetImages/Cat/cat.2375.jpg
# /tmp/PetImages/Cat/cat.791.jpg
# /tmp/PetImages/Cat/cat.39.jpg
# /tmp/PetImages/Cat/cat.618.jpg
# /tmp/PetImages/Cat/cat.279.jpg
# /tmp/PetImages/Cat/cat.888.jpg
# /tmp/PetImages/Cat/cat.2309.jpg
# /tmp/PetImages/Cat/cat.859.jpg
# /tmp/PetImages/Cat/cat.573.jpg
# /tmp/PetImages/Cat/cat.901.jpg
# /tmp/PetImages/Cat/cat.2251.jpg
# /tmp/PetImages/Cat/cat.112.jpg
# /tmp/PetImages/Cat/cat.94.jpg
# /tmp/PetImages/Cat/cat.2197.jpg
# /tmp/PetImages/Cat/cat.2146.jpg
# /tmp/PetImages/Cat/cat.45.jpg
# /tmp/PetImages/Cat/cat.664.jpg
# /tmp/PetImages/Cat/cat.2280.jpg
# /tmp/PetImages/Cat/cat.205.jpg
# /tmp/PetImages/Cat/cat.488.jpg
# /tmp/PetImages/Cat/cat.459.jpg
# /tmp/PetImages/Cat/cat.501.jpg
# /tmp/PetImages/Cat/cat.973.jpg
# /tmp/PetImages/Cat/cat.2223.jpg
# /tmp/PetImages/Cat/cat.160.jpg
# /tmp/PetImages/Cat/cat.2134.jpg
# /tmp/PetImages/Cat/cat.616.jpg
# /tmp/PetImages/Cat/cat.37.jpg
# /tmp/PetImages/Cat/cat.277.jpg
# /tmp/PetImages/Cat/cat.2010.jpg
# /tmp/PetImages/Cat/cat.732.jpg
# /tmp/PetImages/Cat/cat.2471.jpg
# /tmp/PetImages/Cat/cat.886.jpg
# /tmp/PetImages/Cat/cat.353.jpg
# /tmp/PetImages/Cat/cat.857.jpg
# /tmp/PetImages/Cat/cat.425.jpg
# /tmp/PetImages/Cat/cat.382.jpg
# /tmp/PetImages/Cat/cat.2307.jpg
# /tmp/PetImages/Cat/cat.2199.jpg
# /tmp/PetImages/Cat/cat.2148.jpg
# /tmp/PetImages/Cat/cat.2017.jpg
# /tmp/PetImages/Cat/cat.735.jpg
# /tmp/PetImages/Cat/cat.2476.jpg
# /tmp/PetImages/Cat/cat.354.jpg
# /tmp/PetImages/Cat/cat.881.jpg
# /tmp/PetImages/Cat/cat.385.jpg
# /tmp/PetImages/Cat/cat.422.jpg
# /tmp/PetImages/Cat/cat.850.jpg
# /tmp/PetImages/Cat/cat.2300.jpg
# /tmp/PetImages/Cat/cat.2258.jpg
# /tmp/PetImages/Cat/cat.908.jpg
# /tmp/PetImages/Cat/cat.2289.jpg
# /tmp/PetImages/Cat/cat.749.jpg
# /tmp/PetImages/Cat/cat.328.jpg
# /tmp/PetImages/Cat/cat.798.jpg
# /tmp/PetImages/Cat/cat.974.jpg
# /tmp/PetImages/Cat/cat.506.jpg
# /tmp/PetImages/Cat/cat.2224.jpg
# /tmp/PetImages/Cat/cat.167.jpg
# /tmp/PetImages/Cat/cat.2133.jpg
# /tmp/PetImages/Cat/cat.30.jpg
# /tmp/PetImages/Cat/cat.611.jpg
# /tmp/PetImages/Cat/cat.270.jpg
# /tmp/PetImages/Dog/
# /tmp/cats-v-dogs/training/dogs/
# /tmp/cats-v-dogs/testing/dogs/
# /tmp/PetImages/Dog/dog.2313.jpg
# /tmp/PetImages/Dog/dog.2465.jpg
# /tmp/PetImages/Dog/dog.878.jpg
# /tmp/PetImages/Dog/dog.2004.jpg
# /tmp/PetImages/Dog/dog.8.jpg
# /tmp/PetImages/Dog/dog.133.jpg
# /tmp/PetImages/Dog/dog.694.jpg
# /tmp/PetImages/Dog/dog.920.jpg
# /tmp/PetImages/Dog/dog.552.jpg
# /tmp/PetImages/Dog/dog.583.jpg
# /tmp/PetImages/Dog/dog.224.jpg
# /tmp/PetImages/Dog/dog.645.jpg
# /tmp/PetImages/Dog/dog.300.jpg
# /tmp/PetImages/Dog/dog.761.jpg
# /tmp/PetImages/Dog/dog.2419.jpg
# /tmp/PetImages/Dog/dog.2078.jpg
# /tmp/PetImages/Dog/dog.476.jpg
# /tmp/PetImages/Dog/dog.804.jpg
# /tmp/PetImages/Dog/dog.289.jpg
# /tmp/PetImages/Dog/dog.2120.jpg
# /tmp/PetImages/Dog/dog.258.jpg
# /tmp/PetImages/Dog/dog.2237.jpg
# /tmp/PetImages/Dog/dog.639.jpg
# /tmp/PetImages/Dog/dog.307.jpg
# /tmp/PetImages/Dog/dog.766.jpg
# /tmp/PetImages/Dog/dog.2368.jpg
# /tmp/PetImages/Dog/dog.803.jpg
# /tmp/PetImages/Dog/dog.471.jpg
# /tmp/PetImages/Dog/dog.148.jpg
# /tmp/PetImages/Dog/dog.529.jpg
# ...
# /tmp/PetImages/Dog/dog.789.jpg
# /tmp/PetImages/Dog/dog.2420.jpg
# /tmp/PetImages/Dog/dog.2387.jpg
# /tmp/PetImages/Dog/dog.2041.jpg
# /tmp/PetImages/Dog/dog.2090.jpg
# /tmp/PetImages/Dog/dog.339.jpg
# /tmp/PetImages/Dog/dog.2356.jpg
# /tmp/PetImages/Dog/dog.758.jpg
# /tmp/PetImages/Dog/dog.261.jpg
# /tmp/PetImages/Dog/dog.600.jpg
# /tmp/PetImages/Dog/dog.176.jpg
# /tmp/PetImages/Dog/dog.2119.jpg
# /tmp/PetImages/Dog/dog.517.jpg
# /tmp/PetImages/Dog/dog.965.jpg
# /tmp/PetImages/Dog/dog.2380.jpg
# /tmp/PetImages/Dog/dog.2427.jpg
# /tmp/PetImages/Dog/dog.448.jpg
# /tmp/PetImages/Dog/dog.2046.jpg
# /tmp/PetImages/Dog/dog.2097.jpg
# /tmp/PetImages/Dog/dog.499.jpg
# /tmp/PetImages/Dog/dog.2351.jpg
# /tmp/PetImages/Dog/dog.266.jpg
# /tmp/PetImages/Dog/dog.607.jpg
# /tmp/PetImages/Dog/dog.2209.jpg
# /tmp/PetImages/Dog/dog.171.jpg
# /tmp/PetImages/Dog/dog.962.jpg
# /tmp/PetImages/Dog/dog.510.jpg
# /tmp/PetImages/Dog/dog.91.jpg
# /tmp/PetImages/Dog/dog.393.jpg
# /tmp/PetImages/Dog/dog.434.jpg
# /tmp/PetImages/Dog/dog.846.jpg
# /tmp/PetImages/Dog/dog.342.jpg
# /tmp/PetImages/Dog/dog.897.jpg
# /tmp/PetImages/Dog/dog.723.jpg
# /tmp/PetImages/Dog/dog.40.jpg
# /tmp/PetImages/Dog/dog.2275.jpg
# /tmp/PetImages/Dog/dog.2162.jpg
# /tmp/PetImages/Dog/dog.2364.jpg
# /tmp/PetImages/Dog/dog.2073.jpg
# /tmp/PetImages/Dog/dog.2412.jpg
# /tmp/PetImages/Dog/dog.282.jpg
# /tmp/PetImages/Dog/dog.957.jpg
# /tmp/PetImages/Dog/dog.525.jpg
# /tmp/PetImages/Dog/dog.144.jpg
# /tmp/PetImages/Dog/dog.632.jpg
# /tmp/PetImages/Dog/dog.195.jpg
# /tmp/PetImages/Dog/dog.253.jpg
# /tmp/PetImages/Dog/dog.986.jpg
# /tmp/PetImages/Dog/dog.716.jpg
# /tmp/PetImages/Dog/dog.2318.jpg
# /tmp/PetImages/Dog/dog.75.jpg
# /tmp/PetImages/Dog/dog.377.jpg
# /tmp/PetImages/Dog/dog.401.jpg
# /tmp/PetImages/Dog/dog.873.jpg
# /tmp/PetImages/Dog/dog.559.jpg
# /tmp/PetImages/Dog/dog.2157.jpg
# /tmp/PetImages/Dog/dog.138.jpg
# /tmp/PetImages/Dog/dog.3.jpg
# /tmp/PetImages/Dog/dog.2291.jpg
# /tmp/PetImages/Dog/dog.2240.jpg
# /tmp/PetImages/Dog/dog.2186.jpg
# /tmp/PetImages/Dog/dog.588.jpg
# /tmp/PetImages/Dog/dog.711.jpg
# /tmp/PetImages/Dog/dog.72.jpg
# /tmp/PetImages/Dog/dog.370.jpg
# /tmp/PetImages/Dog/dog.2008.jpg
# /tmp/PetImages/Dog/dog.874.jpg
# /tmp/PetImages/Dog/dog.406.jpg
# /tmp/PetImages/Dog/dog.2469.jpg
# /tmp/PetImages/Dog/dog.2150.jpg
# /tmp/PetImages/Dog/dog.4.jpg
# /tmp/PetImages/Dog/dog.698.jpg
# /tmp/PetImages/Dog/dog.2296.jpg
# /tmp/PetImages/Dog/dog.2247.jpg
# /tmp/PetImages/Dog/dog.649.jpg
# /tmp/PetImages/Dog/dog.2181.jpg
# /tmp/PetImages/Dog/dog.228.jpg
# /tmp/PetImages/Dog/dog.2363.jpg
# /tmp/PetImages/Dog/dog.808.jpg
# /tmp/PetImages/Dog/dog.2074.jpg
# /tmp/PetImages/Dog/dog.2415.jpg
# /tmp/PetImages/Dog/dog.522.jpg
# /tmp/PetImages/Dog/dog.950.jpg
# /tmp/PetImages/Dog/dog.285.jpg
# /tmp/PetImages/Dog/dog.143.jpg
# /tmp/PetImages/Dog/dog.192.jpg
# /tmp/PetImages/Dog/dog.635.jpg
# /tmp/PetImages/Dog/dog.981.jpg
# /tmp/PetImages/Dog/dog.254.jpg
# /tmp/PetImages/Dog/dog.2311.jpg
# /tmp/PetImages/Dog/dog.408.jpg
# /tmp/PetImages/Dog/dog.2006.jpg
# /tmp/PetImages/Dog/dog.2467.jpg
# /tmp/PetImages/Dog/dog.550.jpg
# /tmp/PetImages/Dog/dog.922.jpg
# /tmp/PetImages/Dog/dog.2298.jpg
# /tmp/PetImages/Dog/dog.696.jpg
# /tmp/PetImages/Dog/dog.131.jpg
# /tmp/PetImages/Dog/dog.647.jpg
# /tmp/PetImages/Dog/dog.2249.jpg
# /tmp/PetImages/Dog/dog.226.jpg
# /tmp/PetImages/Dog/dog.581.jpg
# /tmp/PetImages/Dog/dog.763.jpg
# /tmp/PetImages/Dog/dog.302.jpg
# /tmp/PetImages/Dog/dog.806.jpg
# /tmp/PetImages/Dog/dog.474.jpg
# /tmp/PetImages/Dog/dog.2122.jpg
# /tmp/PetImages/Dog/dog.2235.jpg
# /tmp/PetImages/Dog/dog.764.jpg
# /tmp/PetImages/Dog/dog.305.jpg
# /tmp/PetImages/Dog/dog.473.jpg
# /tmp/PetImages/Dog/dog.801.jpg
# /tmp/PetImages/Dog/dog.959.jpg
# /tmp/PetImages/Dog/dog.2125.jpg
# /tmp/PetImages/Dog/dog.2232.jpg
# /tmp/PetImages/Dog/dog.988.jpg
# /tmp/PetImages/Dog/dog.2316.jpg
# /tmp/PetImages/Dog/dog.718.jpg
# /tmp/PetImages/Dog/dog.379.jpg
# /tmp/PetImages/Dog/dog.2001.jpg
# /tmp/PetImages/Dog/dog.2460.jpg
# /tmp/PetImages/Dog/dog.2159.jpg
# /tmp/PetImages/Dog/dog.925.jpg
# /tmp/PetImages/Dog/dog.557.jpg
# /tmp/PetImages/Dog/dog.136.jpg
# /tmp/PetImages/Dog/dog.691.jpg
# /tmp/PetImages/Dog/dog.640.jpg
# /tmp/PetImages/Dog/dog.586.jpg
# /tmp/PetImages/Dog/dog.221.jpg
# /tmp/PetImages/Dog/dog.2188.jpg
# /tmp/PetImages/Dog/dog.2100.jpg
# /tmp/PetImages/Dog/dog.278.jpg
# /tmp/PetImages/Dog/dog.2217.jpg
# /tmp/PetImages/Dog/dog.619.jpg
# /tmp/PetImages/Dog/dog.487.jpg
# /tmp/PetImages/Dog/dog.320.jpg
# /tmp/PetImages/Dog/dog.2089.jpg
# /tmp/PetImages/Dog/dog.741.jpg
# /tmp/PetImages/Dog/dog.22.jpg
# /tmp/PetImages/Dog/dog.2439.jpg
# /tmp/PetImages/Dog/dog.790.jpg
# /tmp/PetImages/Dog/dog.2058.jpg
# /tmp/PetImages/Dog/dog.824.jpg
# /tmp/PetImages/Dog/dog.456.jpg
# /tmp/PetImages/Dog/dog.113.jpg
# /tmp/PetImages/Dog/dog.572.jpg
# /tmp/PetImages/Dog/dog.900.jpg
# /tmp/PetImages/Dog/dog.204.jpg
# /tmp/PetImages/Dog/dog.665.jpg
# /tmp/PetImages/Dog/dog.889.jpg
# /tmp/PetImages/Dog/dog.2494.jpg
# /tmp/PetImages/Dog/dog.2333.jpg
# /tmp/PetImages/Dog/dog.2445.jpg
# /tmp/PetImages/Dog/dog.858.jpg
# /tmp/PetImages/Dog/dog.2024.jpg
# /tmp/PetImages/Dog/dog.114.jpg
# /tmp/PetImages/Dog/dog.907.jpg
# /tmp/PetImages/Dog/dog.575.jpg
# /tmp/PetImages/Dog/dog.203.jpg
# /tmp/PetImages/Dog/dog.662.jpg
# /tmp/PetImages/Dog/dog.2334.jpg
# /tmp/PetImages/Dog/dog.2493.jpg
# /tmp/PetImages/Dog/dog.59.jpg
# /tmp/PetImages/Dog/dog.2442.jpg
# /tmp/PetImages/Dog/dog.88.jpg
# /tmp/PetImages/Dog/dog.2023.jpg
# /tmp/PetImages/Dog/dog.168.jpg
# /tmp/PetImages/Dog/dog.509.jpg
# /tmp/PetImages/Dog/dog.2107.jpg
# /tmp/PetImages/Dog/dog.2210.jpg
# /tmp/PetImages/Dog/dog.327.jpg
# /tmp/PetImages/Dog/dog.480.jpg
# /tmp/PetImages/Dog/dog.746.jpg
# /tmp/PetImages/Dog/dog.25.jpg
# /tmp/PetImages/Dog/dog.2348.jpg
# /tmp/PetImages/Dog/dog.2399.jpg
# /tmp/PetImages/Dog/dog.797.jpg
# /tmp/PetImages/Dog/dog.451.jpg
# /tmp/PetImages/Dog/dog.823.jpg
# /tmp/PetImages/Dog/dog.909.jpg
# /tmp/PetImages/Dog/dog.2175.jpg
# /tmp/PetImages/Dog/dog.2262.jpg
# /tmp/PetImages/Dog/dog.880.jpg
# /tmp/PetImages/Dog/dog.355.jpg
# /tmp/PetImages/Dog/dog.734.jpg
# /tmp/PetImages/Dog/dog.57.jpg
# /tmp/PetImages/Dog/dog.86.jpg
# /tmp/PetImages/Dog/dog.423.jpg
# /tmp/PetImages/Dog/dog.851.jpg
# /tmp/PetImages/Dog/dog.384.jpg
# /tmp/PetImages/Dog/dog.166.jpg
# /tmp/PetImages/Dog/dog.2109.jpg
# /tmp/PetImages/Dog/dog.975.jpg
# /tmp/PetImages/Dog/dog.507.jpg
# /tmp/PetImages/Dog/dog.271.jpg
# /tmp/PetImages/Dog/dog.610.jpg
# /tmp/PetImages/Dog/dog.2080.jpg
# /tmp/PetImages/Dog/dog.329.jpg
# /tmp/PetImages/Dog/dog.2346.jpg
# /tmp/PetImages/Dog/dog.748.jpg
# /tmp/PetImages/Dog/dog.799.jpg
# /tmp/PetImages/Dog/dog.2430.jpg
# /tmp/PetImages/Dog/dog.2397.jpg
# /tmp/PetImages/Dog/dog.2051.jpg
# /tmp/PetImages/Dog/dog.161.jpg
# /tmp/PetImages/Dog/dog.500.jpg
# /tmp/PetImages/Dog/dog.972.jpg
# /tmp/PetImages/Dog/dog.276.jpg
# /tmp/PetImages/Dog/dog.617.jpg
# /tmp/PetImages/Dog/dog.2219.jpg
# /tmp/PetImages/Dog/dog.2087.jpg
# /tmp/PetImages/Dog/dog.489.jpg
# /tmp/PetImages/Dog/dog.2341.jpg
# /tmp/PetImages/Dog/dog.2390.jpg
# /tmp/PetImages/Dog/dog.2437.jpg
# /tmp/PetImages/Dog/dog.458.jpg
# /tmp/PetImages/Dog/dog.2056.jpg
# /tmp/PetImages/Dog/dog.2172.jpg
# /tmp/PetImages/Dog/dog.2265.jpg
# /tmp/PetImages/Dog/dog.352.jpg
# /tmp/PetImages/Dog/dog.887.jpg
# /tmp/PetImages/Dog/dog.733.jpg
# /tmp/PetImages/Dog/dog.50.jpg
# /tmp/PetImages/Dog/dog.81.jpg
# /tmp/PetImages/Dog/dog.383.jpg
# /tmp/PetImages/Dog/dog.856.jpg
# /tmp/PetImages/Dog/dog.424.jpg
# /tmp/PetImages/Dog/dog.622.jpg
# /tmp/PetImages/Dog/dog.185.jpg
# /tmp/PetImages/Dog/dog.243.jpg
# /tmp/PetImages/Dog/dog.996.jpg
# /tmp/PetImages/Dog/dog.292.jpg
# /tmp/PetImages/Dog/dog.535.jpg
# /tmp/PetImages/Dog/dog.947.jpg
# /tmp/PetImages/Dog/dog.154.jpg
# /tmp/PetImages/Dog/dog.2063.jpg
# /tmp/PetImages/Dog/dog.2402.jpg
# /tmp/PetImages/Dog/dog.19.jpg
# /tmp/PetImages/Dog/dog.2374.jpg
# /tmp/PetImages/Dog/dog.2250.jpg
# /tmp/PetImages/Dog/dog.2196.jpg
# /tmp/PetImages/Dog/dog.598.jpg
# /tmp/PetImages/Dog/dog.549.jpg
# /tmp/PetImages/Dog/dog.2147.jpg
# /tmp/PetImages/Dog/dog.128.jpg
# /tmp/PetImages/Dog/dog.2281.jpg
# /tmp/PetImages/Dog/dog.863.jpg
# /tmp/PetImages/Dog/dog.411.jpg
# /tmp/PetImages/Dog/dog.706.jpg
# /tmp/PetImages/Dog/dog.2308.jpg
# /tmp/PetImages/Dog/dog.65.jpg
# /tmp/PetImages/Dog/dog.367.jpg
# /tmp/PetImages/Dog/dog.2257.jpg
# /tmp/PetImages/Dog/dog.659.jpg
# /tmp/PetImages/Dog/dog.2191.jpg
# /tmp/PetImages/Dog/dog.238.jpg
# /tmp/PetImages/Dog/dog.2140.jpg
# /tmp/PetImages/Dog/dog.688.jpg
# /tmp/PetImages/Dog/dog.2286.jpg
# /tmp/PetImages/Dog/dog.2018.jpg
# /tmp/PetImages/Dog/dog.416.jpg
# /tmp/PetImages/Dog/dog.864.jpg
# /tmp/PetImages/Dog/dog.2479.jpg
# /tmp/PetImages/Dog/dog.701.jpg
# /tmp/PetImages/Dog/dog.62.jpg
# /tmp/PetImages/Dog/dog.360.jpg
# /tmp/PetImages/Dog/dog.182.jpg
# /tmp/PetImages/Dog/dog.625.jpg
# /tmp/PetImages/Dog/dog.991.jpg
# /tmp/PetImages/Dog/dog.244.jpg
# /tmp/PetImages/Dog/dog.940.jpg
# /tmp/PetImages/Dog/dog.532.jpg
# /tmp/PetImages/Dog/dog.295.jpg
# /tmp/PetImages/Dog/dog.153.jpg
# /tmp/PetImages/Dog/dog.818.jpg
# /tmp/PetImages/Dog/dog.2064.jpg
# /tmp/PetImages/Dog/dog.2405.jpg
# /tmp/PetImages/Dog/dog.2373.jpg
# /tmp/PetImages/Dog/dog.657.jpg
# /tmp/PetImages/Dog/dog.2259.jpg
# /tmp/PetImages/Dog/dog.236.jpg
# /tmp/PetImages/Dog/dog.591.jpg
# /tmp/PetImages/Dog/dog.932.jpg
# /tmp/PetImages/Dog/dog.540.jpg
# /tmp/PetImages/Dog/dog.2288.jpg
# /tmp/PetImages/Dog/dog.686.jpg
# /tmp/PetImages/Dog/dog.121.jpg
# /tmp/PetImages/Dog/dog.418.jpg
# /tmp/PetImages/Dog/dog.2016.jpg
# /tmp/PetImages/Dog/dog.2477.jpg
# /tmp/PetImages/Dog/dog.2301.jpg
# /tmp/PetImages/Dog/dog.2225.jpg
# /tmp/PetImages/Dog/dog.2132.jpg
# /tmp/PetImages/Dog/dog.464.jpg
# /tmp/PetImages/Dog/dog.816.jpg
# /tmp/PetImages/Dog/dog.773.jpg
# /tmp/PetImages/Dog/dog.10.jpg
# /tmp/PetImages/Dog/dog.312.jpg
# /tmp/PetImages/Dog/dog.2222.jpg
# /tmp/PetImages/Dog/dog.998.jpg
# /tmp/PetImages/Dog/dog.949.jpg
# /tmp/PetImages/Dog/dog.2135.jpg
# /tmp/PetImages/Dog/dog.811.jpg
# /tmp/PetImages/Dog/dog.463.jpg
# /tmp/PetImages/Dog/dog.774.jpg
# /tmp/PetImages/Dog/dog.17.jpg
# /tmp/PetImages/Dog/dog.315.jpg
# /tmp/PetImages/Dog/dog.650.jpg
# /tmp/PetImages/Dog/dog.596.jpg
# /tmp/PetImages/Dog/dog.231.jpg
# /tmp/PetImages/Dog/dog.2198.jpg
# /tmp/PetImages/Dog/dog.2149.jpg
# /tmp/PetImages/Dog/dog.547.jpg
# /tmp/PetImages/Dog/dog.935.jpg
# /tmp/PetImages/Dog/dog.126.jpg
# /tmp/PetImages/Dog/dog.681.jpg
# /tmp/PetImages/Dog/dog.2011.jpg
# /tmp/PetImages/Dog/dog.2470.jpg
# /tmp/PetImages/Dog/dog.2306.jpg
# /tmp/PetImages/Dog/dog.708.jpg
# /tmp/PetImages/Dog/dog.369.jpg
# /tmp/PetImages/Dog/dog.765.jpg
# /tmp/PetImages/Dog/dog.304.jpg
# /tmp/PetImages/Dog/dog.472.jpg
# /tmp/PetImages/Dog/dog.800.jpg
# /tmp/PetImages/Dog/dog.2124.jpg
# /tmp/PetImages/Dog/dog.958.jpg
# /tmp/PetImages/Dog/dog.2233.jpg
# /tmp/PetImages/Dog/dog.989.jpg
# /tmp/PetImages/Dog/dog.719.jpg
# /tmp/PetImages/Dog/dog.2317.jpg
# /tmp/PetImages/Dog/dog.378.jpg
# /tmp/PetImages/Dog/dog.2000.jpg
# /tmp/PetImages/Dog/dog.2461.jpg
# /tmp/PetImages/Dog/dog.924.jpg
# /tmp/PetImages/Dog/dog.556.jpg
# /tmp/PetImages/Dog/dog.2158.jpg
# /tmp/PetImages/Dog/dog.690.jpg
# /tmp/PetImages/Dog/dog.137.jpg
# /tmp/PetImages/Dog/dog.641.jpg
# /tmp/PetImages/Dog/dog.2189.jpg
# /tmp/PetImages/Dog/dog.220.jpg
# /tmp/PetImages/Dog/dog.587.jpg
# /tmp/PetImages/Dog/dog.2310.jpg
# /tmp/PetImages/Dog/dog.2007.jpg
# /tmp/PetImages/Dog/dog.409.jpg
# /tmp/PetImages/Dog/dog.2466.jpg
# /tmp/PetImages/Dog/dog.551.jpg
# /tmp/PetImages/Dog/dog.923.jpg
# /tmp/PetImages/Dog/dog.130.jpg
# /tmp/PetImages/Dog/dog.697.jpg
# /tmp/PetImages/Dog/dog.2299.jpg
# /tmp/PetImages/Dog/dog.2248.jpg
# /tmp/PetImages/Dog/dog.646.jpg
# /tmp/PetImages/Dog/dog.580.jpg
# /tmp/PetImages/Dog/dog.227.jpg
# /tmp/PetImages/Dog/dog.762.jpg
# /tmp/PetImages/Dog/dog.303.jpg
# /tmp/PetImages/Dog/dog.807.jpg
# /tmp/PetImages/Dog/dog.475.jpg
# /tmp/PetImages/Dog/dog.2123.jpg
# /tmp/PetImages/Dog/dog.2234.jpg
# /tmp/PetImages/Dog/dog.73.jpg
# /tmp/PetImages/Dog/dog.710.jpg
# /tmp/PetImages/Dog/dog.371.jpg
# /tmp/PetImages/Dog/dog.875.jpg
# /tmp/PetImages/Dog/dog.407.jpg
# /tmp/PetImages/Dog/dog.2009.jpg
# /tmp/PetImages/Dog/dog.2468.jpg
# /tmp/PetImages/Dog/dog.2151.jpg
# /tmp/PetImages/Dog/dog.2297.jpg
# /tmp/PetImages/Dog/dog.5.jpg
# /tmp/PetImages/Dog/dog.699.jpg
# /tmp/PetImages/Dog/dog.648.jpg
# /tmp/PetImages/Dog/dog.2246.jpg
# /tmp/PetImages/Dog/dog.229.jpg
# /tmp/PetImages/Dog/dog.2180.jpg
# /tmp/PetImages/Dog/dog.2362.jpg
# /tmp/PetImages/Dog/dog.2075.jpg
# /tmp/PetImages/Dog/dog.809.jpg
# /tmp/PetImages/Dog/dog.2414.jpg
# /tmp/PetImages/Dog/dog.284.jpg
# /tmp/PetImages/Dog/dog.523.jpg
# /tmp/PetImages/Dog/dog.951.jpg
# /tmp/PetImages/Dog/dog.142.jpg
# /tmp/PetImages/Dog/dog.634.jpg
# /tmp/PetImages/Dog/dog.193.jpg
# /tmp/PetImages/Dog/dog.255.jpg
# /tmp/PetImages/Dog/dog.980.jpg
# /tmp/PetImages/Dog/dog.2365.jpg
# /tmp/PetImages/Dog/dog.2072.jpg
# /tmp/PetImages/Dog/dog.2413.jpg
# /tmp/PetImages/Dog/dog.956.jpg
# /tmp/PetImages/Dog/dog.524.jpg
# /tmp/PetImages/Dog/dog.283.jpg
# /tmp/PetImages/Dog/dog.145.jpg
# /tmp/PetImages/Dog/dog.194.jpg
# /tmp/PetImages/Dog/dog.633.jpg
# /tmp/PetImages/Dog/dog.987.jpg
# /tmp/PetImages/Dog/dog.252.jpg
# /tmp/PetImages/Dog/dog.74.jpg
# /tmp/PetImages/Dog/dog.2319.jpg
# /tmp/PetImages/Dog/dog.717.jpg
# /tmp/PetImages/Dog/dog.376.jpg
# /tmp/PetImages/Dog/dog.400.jpg
# /tmp/PetImages/Dog/dog.872.jpg
# /tmp/PetImages/Dog/dog.2156.jpg
# /tmp/PetImages/Dog/dog.558.jpg
# /tmp/PetImages/Dog/dog.2290.jpg
# /tmp/PetImages/Dog/dog.139.jpg
# /tmp/PetImages/Dog/dog.2.jpg
# /tmp/PetImages/Dog/dog.2241.jpg
# /tmp/PetImages/Dog/dog.589.jpg
# /tmp/PetImages/Dog/dog.2187.jpg
# /tmp/PetImages/Dog/dog.2426.jpg
# /tmp/PetImages/Dog/dog.2381.jpg
# /tmp/PetImages/Dog/dog.2047.jpg
# /tmp/PetImages/Dog/dog.449.jpg
# /tmp/PetImages/Dog/dog.498.jpg
# /tmp/PetImages/Dog/dog.2096.jpg
# /tmp/PetImages/Dog/dog.2350.jpg
# /tmp/PetImages/Dog/dog.267.jpg
# /tmp/PetImages/Dog/dog.2208.jpg
# /tmp/PetImages/Dog/dog.606.jpg
# /tmp/PetImages/Dog/dog.170.jpg
# /tmp/PetImages/Dog/dog.963.jpg
# /tmp/PetImages/Dog/dog.511.jpg
# /tmp/PetImages/Dog/dog.90.jpg
# /tmp/PetImages/Dog/dog.435.jpg
# /tmp/PetImages/Dog/dog.847.jpg
# /tmp/PetImages/Dog/dog.392.jpg
# /tmp/PetImages/Dog/dog.896.jpg
# /tmp/PetImages/Dog/dog.343.jpg
# /tmp/PetImages/Dog/dog.41.jpg
# /tmp/PetImages/Dog/dog.722.jpg
# /tmp/PetImages/Dog/dog.2274.jpg
# /tmp/PetImages/Dog/dog.2163.jpg
# /tmp/PetImages/Dog/dog.97.jpg
# /tmp/PetImages/Dog/dog.395.jpg
# /tmp/PetImages/Dog/dog.840.jpg
# /tmp/PetImages/Dog/dog.432.jpg
# /tmp/PetImages/Dog/dog.344.jpg
# /tmp/PetImages/Dog/dog.891.jpg
# /tmp/PetImages/Dog/dog.46.jpg
# /tmp/PetImages/Dog/dog.725.jpg
# /tmp/PetImages/Dog/dog.2273.jpg
# /tmp/PetImages/Dog/dog.2164.jpg
# /tmp/PetImages/Dog/dog.918.jpg
# /tmp/PetImages/Dog/dog.2386.jpg
# /tmp/PetImages/Dog/dog.2421.jpg
# /tmp/PetImages/Dog/dog.788.jpg
# /tmp/PetImages/Dog/dog.2040.jpg
# /tmp/PetImages/Dog/dog.338.jpg
# /tmp/PetImages/Dog/dog.2091.jpg
# /tmp/PetImages/Dog/dog.759.jpg
# /tmp/PetImages/Dog/dog.2357.jpg
# /tmp/PetImages/Dog/dog.260.jpg
# /tmp/PetImages/Dog/dog.601.jpg
# /tmp/PetImages/Dog/dog.177.jpg
# /tmp/PetImages/Dog/dog.516.jpg
# /tmp/PetImages/Dog/dog.964.jpg
# /tmp/PetImages/Dog/dog.2118.jpg
# /tmp/PetImages/Dog/dog.2453.jpg
# /tmp/PetImages/Dog/dog.99.jpg
# /tmp/PetImages/Dog/dog.2032.jpg
# /tmp/PetImages/Dog/dog.2482.jpg
# /tmp/PetImages/Dog/dog.48.jpg
# /tmp/PetImages/Dog/dog.2325.jpg
# /tmp/PetImages/Dog/dog.212.jpg
# /tmp/PetImages/Dog/dog.673.jpg
# /tmp/PetImages/Dog/dog.105.jpg
# /tmp/PetImages/Dog/dog.564.jpg
# /tmp/PetImages/Dog/dog.916.jpg
# /tmp/PetImages/Dog/dog.786.jpg
# /tmp/PetImages/Dog/dog.2388.jpg
# /tmp/PetImages/Dog/dog.832.jpg
# /tmp/PetImages/Dog/dog.440.jpg
# /tmp/PetImages/Dog/dog.491.jpg
# /tmp/PetImages/Dog/dog.336.jpg
# /tmp/PetImages/Dog/dog.2359.jpg
# /tmp/PetImages/Dog/dog.34.jpg
# /tmp/PetImages/Dog/dog.757.jpg
# /tmp/PetImages/Dog/dog.2201.jpg
# /tmp/PetImages/Dog/dog.179.jpg
# /tmp/PetImages/Dog/dog.2116.jpg
# /tmp/PetImages/Dog/dog.518.jpg
# /tmp/PetImages/Dog/dog.781.jpg
# /tmp/PetImages/Dog/dog.2428.jpg
# /tmp/PetImages/Dog/dog.447.jpg
# /tmp/PetImages/Dog/dog.835.jpg
# /tmp/PetImages/Dog/dog.2049.jpg
# /tmp/PetImages/Dog/dog.2098.jpg
# /tmp/PetImages/Dog/dog.331.jpg
# /tmp/PetImages/Dog/dog.496.jpg
# /tmp/PetImages/Dog/dog.33.jpg
# /tmp/PetImages/Dog/dog.750.jpg
# /tmp/PetImages/Dog/dog.269.jpg
# /tmp/PetImages/Dog/dog.608.jpg
# /tmp/PetImages/Dog/dog.2206.jpg
# /tmp/PetImages/Dog/dog.2111.jpg
# /tmp/PetImages/Dog/dog.2454.jpg
# /tmp/PetImages/Dog/dog.2035.jpg
# /tmp/PetImages/Dog/dog.849.jpg
# /tmp/PetImages/Dog/dog.898.jpg
# /tmp/PetImages/Dog/dog.2322.jpg
# /tmp/PetImages/Dog/dog.2485.jpg
# /tmp/PetImages/Dog/dog.215.jpg
# /tmp/PetImages/Dog/dog.674.jpg
# /tmp/PetImages/Dog/dog.102.jpg
# /tmp/PetImages/Dog/dog.911.jpg
# /tmp/PetImages/Dog/dog.563.jpg

# %%
print(len(os.listdir('/tmp/cats-v-dogs/training/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/training/dogs/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/cats/')))
print(len(os.listdir('/tmp/cats-v-dogs/testing/dogs/')))

# Expected output:
# 1350
# 1350
# 150
# 150
# Out:
# 1350
# 1350
# 150
# 150

# %%
# DEFINE A KERAS MODEL TO CLASSIFY CATS V DOGS
# USE AT LEAST 3 CONVOLUTION LAYERS
model = tf.keras.models.Sequential([
# YOUR CODE HERE
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2), 
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(), 
    tf.keras.layers.Dense(512, activation='relu'), 
    tf.keras.layers.Dense(1, activation='sigmoid')  
])

model.compile(optimizer=RMSprop(lr=0.001), loss='binary_crossentropy', metrics=['acc'])

# %% [markdown]
# # NOTE:
#
# In the cell below you **MUST** use a batch size of 10 (`batch_size=10`) for the `train_generator` and the `validation_generator`. Using a batch size greater than 10 will exceed memory limits on the Coursera platform.

# %%
TRAINING_DIR = "/tmp/cats-v-dogs/training"
train_datagen = ImageDataGenerator(rescale=1./255)

# NOTE: YOU MUST USE A BATCH SIZE OF 10 (batch_size=10) FOR THE 
# TRAIN GENERATOR.
train_generator = train_datagen.flow_from_directory(
        TRAINING_DIR,  
        target_size=(150, 150), 
        batch_size=10,
        class_mode='binary')

VALIDATION_DIR = "/tmp/cats-v-dogs/testing"
validation_datagen = ImageDataGenerator(rescale=1./255)

# NOTE: YOU MUST USE A BACTH SIZE OF 10 (batch_size=10) FOR THE 
# VALIDATION GENERATOR.
validation_generator = validation_datagen.flow_from_directory(VALIDATION_DIR,
                                                        target_size = (150, 150),
                                                         batch_size=10,
                                                         class_mode  = 'binary')



# Expected Output:
# Found 2700 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.
# Out:
# Found 2700 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.

# %%
history = model.fit_generator(train_generator,
                              epochs=2,
                              verbose=1,
                              validation_data=validation_generator)
# Out:
# Epoch 1/2
# 270/270 [==============================] - 35s 130ms/step - loss: 1.0575 - acc: 0.5759 - val_loss: 0.6238 - val_acc: 0.6767
# Epoch 2/2
# 270/270 [==============================] - 30s 110ms/step - loss: 0.5873 - acc: 0.6911 - val_loss: 0.5611 - val_acc: 0.6867

# %%
# PLOT LOSS AND ACCURACY
# %matplotlib inline

import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['acc']
val_acc=history.history['val_acc']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")


plt.title('Training and validation loss')

# Desired output. Charts with training and validation metrics. No crash :)
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# # Submission Instructions

# %%
# Now click the 'Submit Assignment' button above.

# %% [markdown]
# # When you're done or would like to take a break, please run the two cells below to save your work and close the Notebook. This will free up resources for your fellow learners.

# %%
# %%javascript
# <!-- Save the notebook -->
# IPython.notebook.save_checkpoint();

# %%
# %%javascript
# IPython.notebook.session.delete();
# window.onbeforeunload = null
# setTimeout(function() { window.close(); }, 1000);
